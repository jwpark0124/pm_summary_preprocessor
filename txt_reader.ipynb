# %%
# !pip install hanja
# Out:
# Requirement already satisfied: hanja in /usr/local/lib/python3.7/dist-packages (0.13.3)
# Requirement already satisfied: pytest in /usr/local/lib/python3.7/dist-packages (from hanja) (3.6.4)
# Requirement already satisfied: pytest-cov in /usr/local/lib/python3.7/dist-packages (from hanja) (2.5.1)
# Requirement already satisfied: pyyaml==5.1.2 in /usr/local/lib/python3.7/dist-packages (from hanja) (5.1.2)
# Requirement already satisfied: coveralls in /usr/local/lib/python3.7/dist-packages (from hanja) (0.5)
# Requirement already satisfied: coverage<3.999,>=3.6 in /usr/local/lib/python3.7/dist-packages (from coveralls->hanja) (3.7.1)
# Requirement already satisfied: docopt>=0.6.1 in /usr/local/lib/python3.7/dist-packages (from coveralls->hanja) (0.6.2)
# Requirement already satisfied: requests>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from coveralls->hanja) (2.23.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=1.0.0->coveralls->hanja) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=1.0.0->coveralls->hanja) (2021.5.30)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=1.0.0->coveralls->hanja) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=1.0.0->coveralls->hanja) (3.0.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from pytest->hanja) (57.4.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from pytest->hanja) (1.15.0)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.7/dist-packages (from pytest->hanja) (21.2.0)
# Requirement already satisfied: pluggy<0.8,>=0.5 in /usr/local/lib/python3.7/dist-packages (from pytest->hanja) (0.7.1)
# Requirement already satisfied: more-itertools>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from pytest->hanja) (8.8.0)
# Requirement already satisfied: atomicwrites>=1.0 in /usr/local/lib/python3.7/dist-packages (from pytest->hanja) (1.4.0)
# Requirement already satisfied: py>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from pytest->hanja) (1.10.0)

# %%
import unicodedata
import hanja
import argparse
from hanja import hangul
import pandas as pd
import csv
import json
import re
from  pprint import pprint
from google.colab import drive
drive.mount('/content/drive')
from glob import glob
import collections
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
sample = sorted(glob("/content/drive/My Drive/Colab Notebooks/task/Minutes(Korean)/회의록 2차/*.txt"))
# pprint(sample)

# %%
# 파일 불러오기

# fname = "/content/drive/My Drive/Colab Notebooks/task/Minutes(Korean)/회의록 1차/284여성(예산결산기금심사)소위01.txt"
# fname = "/content/drive/My Drive/Colab Notebooks/task/Minutes(Korean)/회의록 1차/311법사(법안심사제1)소위01(12.11.15).txt"
# fname = "/content/drive/My Drive/Colab Notebooks/task/Minutes(Korean)/회의록 1차/311환노(법안심사)소위01(12.9.17).txt"
# fname = "/content/drive/My Drive/Colab Notebooks/task/Minutes(Korean)/회의록 1차/320환노(예산결산기금심사)소위03(13.11.28).txt"
# fname = "/content/drive/My Drive/Colab Notebooks/task/Minutes(Korean)/회의록 1차/321교문(예산결산기금심사)소위03(13.12.16).txt"
# fname = "/content/drive/My Drive/Colab Notebooks/task/Minutes(Korean)/회의록 1차/321국토(교통법안심사)소위01(13.12.12).txt"
# fname = "/content/drive/My Drive/Colab Notebooks/task/Minutes(Korean)/회의록 1차/322국토(민투mrg대책)소위01(14.2.26).txt"
# fname = "/content/drive/My Drive/Colab Notebooks/task/Minutes(Korean)/회의록 1차/322국토(철도산업발전)소위01(14.2.7).txt"
fname = "/content/drive/My Drive/Colab Notebooks/task/Minutes(Korean)/회의록 1차/323국토(철도산업발전)소위02(14.4.10).txt"
# fname = "/content/drive/My Drive/Colab Notebooks/task/Minutes(Korean)/회의록 1차/320교문(청원심사)소위01(13.11.18).txt"
# fname = "/content/drive/My Drive/Colab Notebooks/task/Minutes(Korean)/회의록 1차/346외통(법안심사)소위02(16.10.28.).txt"
# fname = "/content/drive/My Drive/Colab Notebooks/task/Minutes(Korean)/회의록 1차/347안행(안전및선거법심사)소위01(16.12.20.).txt"
# fname = "/content/drive/My Drive/Colab Notebooks/task/Minutes(Korean)/회의록 1차/354환노(고용노동)소위03(17.9.28.).txt"

# fname = "/content/drive/My Drive/Colab Notebooks/task/Minutes(Korean)/회의록 2차/311교과(법안심사)소위03(12.9.24).txt"
# fname = "/content/drive/My Drive/Colab Notebooks/task/Minutes(Korean)/회의록 2차/311국토(예산결산기금심사)소위02(12.11.7).txt"
# fname = "/content/drive/My Drive/Colab Notebooks/task/Minutes(Korean)/회의록 2차/311법사(예산결산심사)소위03(12.11.21).txt"
# fname = "/content/drive/My Drive/Colab Notebooks/task/Minutes(Korean)/회의록 2차/311법사(예산결산심사)소위04(12.12.3).txt"
# fname = "/content/drive/My Drive/Colab Notebooks/task/Minutes(Korean)/회의록 2차/311외통(법안심사)소위03(12.11.19).txt"
# fname = "/content/drive/My Drive/Colab Notebooks/task/Minutes(Korean)/회의록 2차/311재정(경제재정)소위03(12.9.24).txt"
# fname = "/content/drive/My Drive/Colab Notebooks/task/Minutes(Korean)/회의록 2차/311재정(예산결산기금심사)소위03(12.11.6).txt"
# fname = "/content/drive/My Drive/Colab Notebooks/task/Minutes(Korean)/회의록 2차/311재정(예산결산기금심사)소위08(12.11.15).txt"

# fname = "/content/drive/My Drive/Colab Notebooks/task/Minutes(Korean)/회의록 2차/311재정(예산결산기금심사)소위09(12.11.20).txt"
# fname = "/content/drive/My Drive/Colab Notebooks/task/Minutes(Korean)/회의록 2차/311행안(법안심사)소위02(12.9.19).txt"
# fname = "/content/drive/My Drive/Colab Notebooks/task/Minutes(Korean)/회의록 2차/313문방(법안심사)소위01(13.2.15).txt"
# fname = "/content/drive/My Drive/Colab Notebooks/task/Minutes(Korean)/회의록 2차/315국방(예산결산심사)소위01(13.4.23).txt"
# fname = "/content/drive/My Drive/Colab Notebooks/task/Minutes(Korean)/회의록 2차/315여성(유엔협약이행정책심사)소위01(13.4.23).txt"
# fname = "/content/drive/My Drive/Colab Notebooks/task/Minutes(Korean)/회의록 2차/315국토(교통법안심사)소위01(13.4.23).txt"
# fname = "/content/drive/My Drive/Colab Notebooks/task/Minutes(Korean)/회의록 2차/315재정(예산결산기금심사)소위03(13.5.3).txt"
# fname = "/content/drive/My Drive/Colab Notebooks/task/Minutes(Korean)/회의록 2차/315재정(조세)소위02(13.4.18).txt"
# fname = "/content/drive/My Drive/Colab Notebooks/task/Minutes(Korean)/회의록 2차/315환노(법안심사)소위02(13.4.17)(공청회).txt"
# fname = "/content/drive/My Drive/Colab Notebooks/task/Minutes(Korean)/회의록 2차/320국토(청원심사)소위01(13.10.8).txt"
# fname = "/content/drive/My Drive/Colab Notebooks/task/Minutes(Korean)/회의록 2차/321법사(예산결산심사)소위02(13.12.12).txt"
# fname = "/content/drive/My Drive/Colab Notebooks/task/Minutes(Korean)/회의록 2차/324법사(법안심사제2)소위01(14.4.22).txt"
# fname = "/content/drive/My Drive/Colab Notebooks/task/Minutes(Korean)/회의록 2차/329법사(법안심사제1)소위01(14.11.6).txt"
# fname = "/content/drive/My Drive/Colab Notebooks/task/Minutes(Korean)/회의록 2차/329재정(예산결산기금심사)소위03(14.11.11).txt"
# fname = "/content/drive/My Drive/Colab Notebooks/task/Minutes(Korean)/회의록 2차/329환노(법안심사)소위06(14.12.8).txt"

# fname = "/content/drive/My Drive/Colab Notebooks/task/Minutes(Korean)/회의록 2차/334안행(예산결산기금심사)소위02(15.7.3).txt"
# fname = "/content/drive/My Drive/Colab Notebooks/task/Minutes(Korean)/회의록 2차/340국방(법률안심사)소위01(16.2.16).txt"
# fname = "/content/drive/My Drive/Colab Notebooks/task/Minutes(Korean)/회의록 2차/346기재(조세)소위08(16.11.28.).txt"
# fname = "/content/drive/My Drive/Colab Notebooks/task/Minutes(Korean)/회의록 2차/348법사(법안심사제1)소위01(17.1.18.).txt"
# fname = "/content/drive/My Drive/Colab Notebooks/task/Minutes(Korean)/회의록 2차/349국방(법률안심사)소위02(17.2.13.)(공청회).txt"
# fname = "/content/drive/My Drive/Colab Notebooks/task/Minutes(Korean)/회의록 2차/337국방(청원심사)소위01(15.11.18).txt"
# fname = "/content/drive/My Drive/Colab Notebooks/task/Minutes(Korean)/회의록 2차/340국방(법률안심사)소위01(16.2.16).txt"
# fname = "/content/drive/My Drive/Colab Notebooks/task/Minutes(Korean)/회의록 2차/340국방(법률안심사)소위01(16.2.16).txt"
# fname = "/content/drive/My Drive/Colab Notebooks/task/Minutes(Korean)/회의록 2차/353기재(조세)소위01(17.8.22.).txt"
# fname = "/content/drive/My Drive/Colab Notebooks/task/Minutes(Korean)/회의록 2차/354여성(법안심사)소위01(17.9.18.)(공청회).txt"
# fname = "/content/drive/My Drive/Colab Notebooks/task/Minutes(Korean)/회의록 2차/356여성(국제규약점검)소위01(18.2.13.).txt"
# fname = "/content/drive/My Drive/Colab Notebooks/task/Minutes(Korean)/회의록 2차/371환노(예산결산기금심사)소위05(19.11.7.).txt"
# fname = "/content/drive/My Drive/Colab Notebooks/task/Minutes(Korean)/회의록 2차/377행안(예산.결산및기금심사)소위01(20.4.28.).txt"
# fname = "/content/drive/My Drive/Colab Notebooks/task/Minutes(Korean)/회의록 2차/364국토(국토법안심사)소위04(18.12.07.)(공청회).txt"
# fname = "/content/drive/My Drive/Colab Notebooks/task/Minutes(Korean)/회의록 2차/364국방(병역특례제도개선)소위02(18.11.29.).txt"
# fname = "/content/drive/My Drive/Colab Notebooks/task/Minutes(Korean)/회의록 2차/349국방(법률안심사)소위02(17.2.13.)(공청회).txt"



# fname = "/content/drive/My Drive/Colab Notebooks/task/Minutes(Korean)/회의록 1,2차/332법사(법안심사제1)소위02(15.5.1).txt"


with open(fname, 'r', encoding='utf-8-sig') as file:
  txt = file.readlines()
  pass
# pprint(txt)

# %%
def clean_up(txt):
  tt = []
  ttt = []
  text = []
  for page in txt:
    sent = page.strip()    
    sent = sent.split("\n")
    tt += sent
  for i in range(len(tt)):
    if tt[i].endswith("."):            
      index = tt[i].rfind('.')
      ttt.append(tt[i][:index] + '. ')
    elif tt[i].endswith("?"):            
      index = tt[i].rfind('?')
      ttt.append(tt[i][:index] + '? ')
    elif tt[i].endswith("!"):            
      index = tt[i].rfind('!')
      ttt.append(tt[i][:index] + '! ')
    else:
      ttt.append(tt[i])
# 이름의 성(김,임,춘..등) 같은경우 외장함수 hanja를 이용해도 한자 코드가 일정한 음으로 변경되지 않을 수 있기 때문에
# 미리 변환해 두어 오류를 방지 ex) 金 -> 김, 금 : 김으로 통일
  for han in range(len(ttt)):    
    ktext = ttt[han].replace('臨', '임').replace("委","위").replace("員",'원').replace("金","김").replace("金","김").replace('淇','기').replace('春','춘').replace("柳","유").replace("李","이").replace("梁","양").replace("羅","나").replace("利","이").replace("勞","노").replace("盧","노").replace("樂","락").replace("樂","락").replace("龍","용").replace("沈","심").replace("呂","려").replace("寧","영")      
    text.append(ktext)    
  return text
text = clean_up(txt)
# pprint(text)

# %%
def clean_up_or(txt):
  # 같은 한자여도 유니코드가 다를 수 있다. 때문에 하나의 형태의 유니코드로 통일시켜 아래와 같이 적용***
  # 다른 한자로 읽어 들이는 오류를 미리 방지. ex) 金 -> 김, 금 : 한자가 같아도 유니코드가 다르다.
  a = unicodedata.normalize('NFC','金')
  b = unicodedata.normalize('NFC',"樂")
  c = unicodedata.normalize('NFC',"柳")
  d = unicodedata.normalize('NFC',"劉")


  text_or =[]  
  tt = []
  ttt = []
  for page in txt:
    sent = page.strip()
    sent = sent.split("\n")      
    tt += sent
  for i in range(len(tt)):
    if tt[i].endswith("."):            
      index = tt[i].rfind('.')
      ttt.append(tt[i][:index] + '. ')
    elif tt[i].endswith("?"):            
      index = tt[i].rfind('?')
      ttt.append(tt[i][:index] + '? ')
    elif tt[i].endswith("!"):            
      index = tt[i].rfind('!')
      ttt.append(tt[i][:index] + '! ')
    else:
      ttt.append(tt[i])
  for han in range(len(ttt)): 
    # ***
    ktext = ttt[han].replace("金",a).replace("金",a).replace("樂",b).replace("樂",b).replace("柳",c).replace("柳",c).replace("劉",d).replace("劉",d)
    text_or.append(ktext) 
  return text_or
text_or = clean_up_or(txt)
# pprint(text_or)

# %%
# yyyymmdd 형태의 날짜 추출
def date_extractor(text):
  pm_date = ''  
  for i in range(7,11):    
    if text[i].startswith("日"):      
      pm_da = text[i].split(' ')      
      pm_dat = pm_da[-1].split("年")            
      year = pm_dat[0]
      mmdd = pm_dat[1].split("(") 
      md = mmdd[0]      
      for i in range(len(md[1])):
        if md[1] == "月":
          month = "0" + md[0]
          if md[3] == "日":
            day = "0" + md[2]
          elif md [4] == "日":
            day = md[2] + md[3]
        elif md[2] == "月":
          month = md[0] + md[1]
          if md[4] == "日":
            day = "0" + md[3]
          elif md [5] == "日":
            day = md[3] + md[4]
      date = year + month + day
    elif text[i].startswith("일"):
      pm_da = text[i].split(' ')      
      pm_dat = pm_da[-1].split("년")            
      year = pm_dat[0]
      mmdd = pm_dat[1].split("(") 
      md = mmdd[0]      
      for i in range(len(md[1])):
        if md[1] == "월":
          month = "0" + md[0]
          if md[3] == "일":
            day = "0" + md[2]
          elif md [4] == "일":
            day = md[2] + md[3]
        elif md[2] == "월":
          month = md[0] + md[1]
          if md[4] == "일":
            day = "0" + md[3]
          elif md [5] == "일":
            day = md[3] + md[4]
      date = year + month + day
  return date     
pm_date = date_extractor(text)
# print(pm_date)

# %%
# 작성자 추출
def author(text):
  pm_author = ''
  for i in range(6,12):
    if text[i].startswith('國') and text[i].endswith('處')  or text[i].startswith('국') and text[i].endswith('처'):
      pm_author = hanja.translate(''.join(text[i].split(' ')),"substitution")
  return pm_author
pm_author = author(text)
# print(pm_author)

# %%
# 안건
def topic_extractor(text):
  pm_topi =[]
  pm_topic =[]
  pm_topict =[]
  pm_topicc = []
  s_start = False
  s_end = False
  break_early = False  
  for i in range(len(text)):
    sent = text[i].strip()
    if sent == '상정된 안건' or sent == '審査된案件' or sent == '심사된 안건':
      s_start = i    
    if sent.endswith('개의)'):
      s_end = i - 5
      break_early = True
      if break_early:
        break             
  while s_start <= s_end:
    s_start += 1
    topic = text[s_start].split('\t')    
    topic = hanja.translate(topic[0],"substitution")
    topic.strip()
    pm_top = topic.split('\n')
    pm_topi += pm_top
  # if pm_topi[-1].endswith(")"):
  #   for s in range(len(pm_topi)):
  #     if not (pm_topi[s].startswith("가") or pm_topi[s].startswith("나") or pm_topi[s].startswith("다") or pm_topi[s].startswith("라") or pm_topi[s].startswith("마") or pm_topi[s].startswith("바") or pm_topi[s].startswith("사")):
  #       pm_topic1 = pm_topi[s] + " / "
  #       pm_topicc += pm_topic1.split('\n')
  #   pm_topicc[-1] = pm_topicc[-1].replace(" / ","")    
  if len(pm_topi) == 1:
    pm_topicc += pm_topi
  elif pm_topi[0].startswith("1") and pm_topi[1].startswith("2"):
    for s in range(len(pm_topi)):
      pm_topic1 = pm_topi[s] + " / "
      pm_topicc += pm_topic1.split('\n')
    pm_topicc[-1] = pm_topicc[-1].replace(" / ","")        
  else:    
    try:      
      if type(int(pm_topi[-1][0])) == int:
        for n in range(len(pm_topi)-1):      
          for m in range(len(pm_topi) -1):        
            if pm_topi[n].startswith("{}".format(m)) and pm_topi[n+1].startswith("가"):
              pm_topic1 = pm_topi[n] + " > "                            
              pm_topicc += pm_topic1.split('\n')
            elif pm_topi[n].startswith("{}".format(m)) and not pm_topi[n+1].startswith("가"):
              pm_topicc += pm_topi[n] + " / "
          if pm_topi[n].startswith("가") or pm_topi[n].startswith("나") or pm_topi[n].startswith("다") or pm_topi[n].startswith("라") or pm_topi[n].startswith("마") or pm_topi[n].startswith("바") or pm_topi[n].startswith("사"):
              pm_topicc += pm_topi[n].split('\n')
        pm_topicc += pm_topi[-1]
    except ValueError:
      for n in range(len(pm_topi)):      
        for m in range(len(pm_topi)):        
          if pm_topi[n].startswith("{}".format(m)) and pm_topi[n+1].startswith("가"):
            pm_topic1 = pm_topi[n] + " > "
            pm_topicc += pm_topic1.split('\n')      
          elif pm_topi[n].startswith("{}".format(m)) and not pm_topi[n+1].startswith("가"):
            pm_topicc += pm_topi[n] + " / "
        if pm_topi[n].startswith("가") or pm_topi[n].startswith("나") or pm_topi[n].startswith("다") or pm_topi[n].startswith("라") or pm_topi[n].startswith("마") or pm_topi[n].startswith("바") or pm_topi[n].startswith("사"):
            pm_topicc += pm_topi[n].split('\n')  
  x = range(len(pm_topi))
  y = range(1, len(pm_topi))
  
  for a, b in zip(x, y):   
    if pm_topicc[a].startswith("가") and pm_topicc[b].startswith("나"):
      pm_topicc[a] = pm_topicc[a] +", "      
    if pm_topicc[a].startswith("나") and pm_topicc[b].startswith("다"):
      pm_topicc[a] = pm_topicc[a] +", "
    if pm_topicc[a].startswith("다") and pm_topicc[b].startswith("라"):
      pm_topicc[a] = pm_topicc[a] +", "
    if pm_topicc[a].startswith("라") and pm_topicc[b].startswith("마"):
      pm_topicc[a] = pm_topicc[a] +", "
    if pm_topicc[a].startswith("마") and pm_topicc[b].startswith("바"):
      pm_topicc[a] = pm_topicc[a] +", "
    if pm_topicc[a].startswith("바") and pm_topicc[b].startswith("사"):
      pm_topicc[a] = pm_topicc[a] +", "
    if pm_topicc[a].startswith("가") and not pm_topicc[b].startswith("나"):
      pm_topicc[a] = pm_topicc[a] + " / "  
    if pm_topicc[a].startswith("나") and not pm_topicc[b].startswith("다"):
      pm_topicc[a] = pm_topicc[a] + " / "
    if pm_topicc[a].startswith("다") and not pm_topicc[b].startswith("라"):
      pm_topicc[a] = pm_topicc[a] + " / "
    if pm_topicc[a].startswith("라") and not pm_topicc[b].startswith("마"):
      pm_topicc[a] = pm_topicc[a] + " / "
    if pm_topicc[a].startswith("마") and not pm_topicc[b].startswith("바"):
      pm_topicc[a] = pm_topicc[a] + " / "
    if pm_topicc[a].startswith("바") and not pm_topicc[b].startswith("사"):
      pm_topicc[a] = pm_topicc[a] + " / "
    if pm_topicc[a].startswith("사") and not pm_topicc[b].startswith("아"):
      pm_topicc[a] = pm_topicc[a] + " / "
  
  for f in range(len(pm_topicc)):
    pm_topict += pm_topicc[f].split('\n')
    pm_topic =''.join(pm_topict)
  
  return pm_topic
pm_topic = topic_extractor(text)
pprint(pm_topic)
# Out:
# '1. 소위원회 활동보고서 채택의 건(계속)'

# %%
# 메타데이터
def meta_extractor(text, pm_date, pm_topic, pm_author, fname):

    meta = {}
    # 카테고리
    pm_category = ''
    for i in range(3,4):
      pm_category += text[i]
      pm_cate = hanja.translate(pm_category, 'substitution')
    
    pm_category = "회의록 > 국회소위원회 > " + pm_cate
    meta['카테고리'] = pm_category
        
    pm_code =''
    for i in range(1,6):
        pm_code += text[i]
        pm_code = hanja.translate(pm_code,'substitution')
    pm_code = pm_code.replace(" ","")
    meta['회의록코드'] = pm_code
    
    # 국회명
    pm_name_ =""
    for i in range(1,3):
      pm_name_ += text[i]
      pm_name = hanja.translate(pm_name_, 'substitution')

    meta['국회명'] = pm_name

    # 회의록 제목
    pm_title =''
    for i in range(1,6):
      if i % 2 == 0:
        pm_title += text[i]
        pm_title = hanja.translate(pm_title,'substitution')  
      elif i % 2 == 1 and i % 5 != 0: 
        pm_title += " " + text[i]
        pm_title = hanja.translate(pm_title,'substitution')            
      elif i % 5 == 0 :
        pm_title += " " + text[i].replace(" ","")
        pm_title = hanja.translate(pm_title,'substitution')          
    meta['회의록제목'] = pm_title
        
    # 작성자    
    meta['작성'] = pm_author

    # 일시    
    meta['일시'] = pm_date

    # 토픽    
    meta['토픽'] = pm_topic

    # 파일명
    f_title = ''
    f_title = fname.split('/')[-1].split('.txt')[0]
    f_title1 = unicodedata.normalize('NFD',f_title)
    file_title = unicodedata.normalize('NFC',f_title1)
    meta['파일명'] = file_title    
    return meta
    
meta = meta_extractor(text, pm_date, pm_topic, pm_author, fname)
# pprint(meta)

# %%
# 본격적 대화(한글화버전)
def dialog_extractor(text):
    dialog = []
    doc = []
    ### 대사 추출 프로그램    
    for page in text:  
        sents = page.split('\n')              
        doc.append(sents)    
    s_start = False
    s_end = False
    break_early =False  
    for sid in range(len(text)):                    
        sent = text[sid].lstrip()        
        if sent.startswith('◯'):
            s_start = sid
            break_early = True
            break                          
        if break_early:
            break
    for sid in range(len(text)):
        sent = text[sid].lstrip()
        if sent.endswith('산회)') or sent.endswith('중지)'):
            s_end = sid       
    for sid in range(len(text)):
        sent = text[sid].lstrip()        
    break_early = False
    doc = []    
    for sid in range(len(text)):
      if sid >= s_start and sid <= s_end - 1:
        sent = text[sid].lstrip()        
        sent = hanja.translate(sent,'substitution').replace("金","김").replace("李","이").replace("梁","양").replace("羅","나").replace("利","이").replace("勞","노").replace("樂","락").replace("盧","노").replace("樂","락").replace("龍","용").replace("沈","심").replace("呂","려").replace("寧","영").replace("宅","택").replace("劉","유")
        if sent.startswith("1.") or sent.startswith("2.") or sent.startswith("3.") or sent.startswith("4.") or sent.startswith("5.") or sent.startswith("가.") or sent.startswith("나.") or sent.startswith("다.") or sent.startswith("라."):
          continue          
        if sent.endswith(")"):      
          continue          
        if sent.startswith('◯'):
          speaker = ' '.join(text[sid].split(' ')[0:3])
          tokens = ' '.join(text[sid].split(' ')[3:])
          sent1 = sent.replace('◯','◯ ')          
          doc.append(sent1)      
        else:
          doc.append(sent)
    doc_p = ''.join(doc)    
    doc_ps = doc_p.split('◯')
    rev_doc = []
    for s in doc_ps:              
            if s == '':
                pass
            elif s.startswith(" "):
                s = '◯'+s                
                rev_doc.append(s)                
            else:                
                rev_doc.append(s)
    dialog += rev_doc
    
    return dialog
dialog = dialog_extractor(text)
# pprint(dialog)

# %%
# 본격적 대화(원본)
def dialog_extractor_or(text_or):
    dialog_or = []
    doc = []
    ### 대사 추출 프로그램       
    for page in text_or:  
        sents = page.split('\n')              
        doc.append(sents)    
    s_start = False
    s_end = False
    break_early =False  
    for sid in range(len(text_or)):                    
        sent = text_or[sid].lstrip()        
        if sent.startswith('◯'):
            s_start = sid
            break_early = True
            break                          
        if break_early:
            break
    for sid in range(len(text_or)):
        sent = text_or[sid].lstrip()
        if sent.endswith('산회)') or sent.endswith('중지)'):
            s_end = sid

    for sid in range(len(text_or)):
        sent = text_or[sid].lstrip()        
    break_early = False
    doc = []
    for sid in range(len(text_or)):
      if sid >= s_start and sid <= s_end - 1:
        sent = text_or[sid].lstrip()
        if sent.startswith("1.") or sent.startswith("2.") or sent.startswith("3.") or sent.startswith("4.") or sent.startswith("5.") or sent.startswith("가.") or sent.startswith("나.") or sent.startswith("다.") or sent.startswith("라."):
          continue          
        if sent.endswith(")"):      
          continue          
        if sent.startswith('◯'):
          speaker = ' '.join(text_or[sid].split(' ')[0:3])
          tokens = ' '.join(text_or[sid].split(' ')[3:])
          sent1 = sent.replace('◯','◯ ')          
          doc.append(sent1)
        else:
          doc.append(sent)
    doc_p = ''.join(doc)    
    doc_ps = doc_p.split('◯')
    rev_doc = []
    for s in doc_ps:               
            if s == '':
                pass
            elif s.startswith(" "):
                s = '◯'+s                
                rev_doc.append(s)                
            else:                
                rev_doc.append(s)
    dialog_or += rev_doc
    
    return dialog_or
dialog_or = dialog_extractor_or(text_or)
# pprint(dialog_or)

# %%
# 대화에 참여자 이름, 직위(한글화)
def speaker_extractor(dialog):
  global persons
  persons =[]
  occups = []
  speaker_ex = []
  for i in range(len(dialog)):
    dialog_s = dialog[i].split(' ')    
    first_t = dialog_s[1]
    second_t = dialog_s[2]
    # print(dialog_s)
    # if first_t.endswith("관") or first_t.endswith("장") or first_t.endswith("위원") or first_t.endswith("참고인") and len(first_t) >= 3:
    if second_t != "의원" and second_t != "위원" and second_t != "委員" and second_t != "議員":
      occup = first_t.replace("◯ ","")
    else:
      person = first_t.replace("◯ ","")
    if second_t == "의원" or second_t == "위원" or second_t == "委員" or second_t == "議員":
      occup = second_t
    else:
      person = second_t    
    
    persons.append(person)
    occups.append(occup)   
  po = []
  for j in range(len(persons)):
    sp = persons[j]+ " " + occups[j]
    po.append(sp)
  
    
  n_po = []
  for v in po:
    if v not in n_po:
      n_po.append(v)    
  for w in range(len(n_po)):
    n_pos = n_po[w].split(' ') 
    speaker_ex.append(n_pos)        
  return speaker_ex
speaker_ex = speaker_extractor(dialog)
# pprint(speaker_ex)

# %%
# 대화에 참여자 이름, 직위
def speaker_extractor_or(dialog_or): 
  
  global personss
  personss =[]
  occups = []
  speaker_ex_or = []
  for i in range(len(dialog_or)):
    dialog_s = dialog_or[i].split(' ')    
    first_t = dialog_s[1]
    second_t = dialog_s[2]    
    # if first_t.endswith("관") or first_t.endswith("장") or first_t.endswith("위원") or first_t.endswith("참고인") and len(first_t) >= 3:
    if second_t != "의원" and second_t != "위원" and second_t != "委員" and second_t != "議員":
      occup = first_t.replace("◯ ","")
    else:
      person = first_t.replace("◯ ","")
    if second_t == "의원" or second_t == "위원" or second_t == "委員" or second_t == "議員":
      occup = second_t
    else:
      person = second_t        
    personss.append(person)
    occups.append(occup)  
  po = []
  for j in range(len(personss)):
    sp = personss[j]+ " " + occups[j]
    po.append(sp)
  # pprint(po)
  n_po = []

  for v in po:
    if v not in n_po:
      n_po.append(v)      
  for w in range(len(n_po)):    
    n_pos = n_po[w].split(' ')    
    speaker_ex_or.append(n_pos) 
  return speaker_ex_or
speaker_ex_or = speaker_extractor_or(dialog_or)
pprint(speaker_ex_or)
# Out:
# [['강석호', '소위원장'],
#  ['김요환', '전문위원'],
#  ['여형구', '국토교통부제2차관'],
#  ['윤후덕', '위원'],
#  ['민홍철', '위원'],
#  ['안효대', '위원'],
#  ['한문희', '한국철도공사경영지원본부장'],
#  ['김경욱', '국토교통부철도국장']]

# %%
# 발언자, 발언(한글수정)
def utterance_extractor(dialog): 
  utterance_id = []
  utterance_form = []  
  
  for i in range(len(dialog)):
    dialog_s = dialog[i].split(' ')
    # first_s = dialog_s[1:3]
    second_s = dialog_s[4:]
    # spk_id = ' '.join(first_s)
    utter = ' '.join(second_s)
    # utterance_id.append(spk_id)
    utterance_form.append(utter)  
  return persons, utterance_form
utterance_ex = utterance_extractor(dialog)
# pprint(utterance_ex)

# %%
# 발언자, 발언(원본)
def utterance_extractor_or(dialog_or): 
  utterance_id = []
  utterance_form = []
  
  for i in range(len(dialog_or)):
    dialog_s = dialog_or[i].split(' ')
    # first_s = dialog_s[1:3]
    second_s = dialog_s[4:]
    # spk_id = ' '.join(first_s)
    utter = ' '.join(second_s)
    # utterance_id.append(spk_id)
    utterance_form.append(utter)
  return personss, utterance_form
utterance_ex_or = utterance_extractor_or(dialog_or)
# pprint(utterance_ex_or)

# %%
# utterance info
def dialog_formatting(utterance_ex, utterance_ex_or):  
  dialog_json = []    
  utterance_id = utterance_ex_or[0]
  utterance_form = utterance_ex[1]
  utterance_form_or = utterance_ex_or[1]  
  # pprint(utterance_form_or)
  for i in range(len(utterance_ex_or[0])):
    d = {}
    d['speaker'] = utterance_id[i]
    d['utterance'] = utterance_form[i] 
    d['utterance_or'] = utterance_form_or[i]      
    
    dialog_json.append(d)      
  # result.append(d)
  return dialog_json
  
dialog_json = dialog_formatting(utterance_ex, utterance_ex_or)
# pprint(dialog_json)

# %%
# speaker info
def speaker_list_extractor(speaker_ex,speaker_ex_or):
  global p_name
  p_name = []  
  speaker_list = []  
    
  for i in range(len(speaker_ex)):        
    name = speaker_ex[i][0]        
    position = speaker_ex[i][1] 
    # o_name = speaker_ex_or[i][0]
    if position != "소위원장대리":
      d = {}      
      d['id'] = name
      # d['age'] = "NA"
      d['occupation'] = position
      # d['sex'] = "NA"
      # d['birthplace'] = "NA"
      # d['principal_residence'] = "NA"
      # d['current_residence'] = "NA"
      # d['original_speaker_id'] = o_name 
      speaker_list.append(d) 
      p_name.append(d['id']) 
    
  return speaker_list
speaker_list = speaker_list_extractor(speaker_ex,speaker_ex_or)
# pprint(speaker_list)

# %%
# speaker info(original)
def speaker_list_extractor_or(speaker_ex,speaker_ex_or):
  global p2_name
  p2_name = []  
  speaker_list = []         
  for i in range(len(speaker_ex)):        
    # name = speaker_ex[i][0]        
    position = speaker_ex[i][1] 
    o_name = speaker_ex_or[i][0]
    if position != "소위원장대리":
      d = {}      
      d['id'] = o_name
      # d['age'] = "NA"
      d['occupation'] = position
      # d['sex'] = "NA"
      # d['birthplace'] = "NA"
      # d['principal_residence'] = "NA"
      # d['current_residence'] = "NA"
      # d['original_speaker_id'] = o_name 
      speaker_list.append(d)
      p2_name.append(d['id'])   
  return speaker_list
speaker_list__ = speaker_list_extractor_or(speaker_ex,speaker_ex_or)
# pprint(speaker_list__)

# %%
def speaker_extractor2_or(text,speaker_list, speaker_list__, speaker_ex):
  s_start = False  
  ss_start = False  
  break_early = False
  s_sentence = []  
  ss_sentence = []  
  sss_sentence =[]
  c_sentence = []
  d_sentence = []
  speaker_list2 = []  
  speaker_list2__2 = []    
  e_sentence = []
  f_sentence = []
  g_sentence = []
  h_sentence = []
  B_member = []
  part2 = False
  part3 = False
  part4 = False
  part5 = False  
  c_end = False
  d_end = False
  e_end = False
  f_end = False
  g_end = False
  h_end = False
  role = ""
  b = 0
  
  # 산회) 이하 제~일) 이상 문장 뽑기
  # for i in range(len(text)):
  #   if text[i].endswith("산회)") or text[i].endswith('중지)'):
  #     s_start = i + 1  
  for i in range(len(text)):
    if text[i].startswith("◯출석") or text[i].startswith("○출석"):
      s_start = i - 1       
      break_early = True
      break 
  break_early = False  
  for i in range(len(text)):
    if text[i].startswith("제") and (text[i].endswith('일)') or text[i].endswith('차')):
      if text[i - 1] == '' and text[i-2] == '' and text[i-3] =='':
        s_end = i - 3
        break_early = True
        break
      break_early = False
      if text[i - 1] == '' and text[i-2] == '':
        s_end = i - 2
        break_early = True
        break
      break_early = False
      if text[i - 1] != '':
        s_end = i
        break_early = True
        break
      break_early = False  
  for sid in range(len(text)):    
    if sid >=s_start and sid < s_end:      
      sub_sentences = hanja.translate(text[sid],"substitution").replace("金","김").replace("李","이").replace("梁","양").replace("羅","나").replace("利","이").replace("勞","노").replace("樂","락").replace("盧","노").replace("樂","락").replace("龍","용").replace("沈","심").replace("宅","택")
      s_sentence.append(sub_sentences) 

  # 출석 위원
  for j in range(len(s_sentence)):    
    if s_sentence[j].startswith("◯") or s_sentence[j].startswith("○"):
      m =  j + 1
      A_member = s_sentence[m].split("  ")      
      break_early = True
      break
  break_early = False   
  # p_name2 = []  
  for t in range(len(A_member)):    
    if A_member[t] not in p_name:      
      name = A_member[t]
      d = {}      
      d['id'] = name
      # d['age'] = "NA"
      d['occupation'] = "위원"
      # d['sex'] = "NA"
      # d['birthplace'] = "NA"
      # d['principal_residence'] = "NA"
      # d['current_residence'] = "NA"
      # d['original_speaker_id'] = name 
      speaker_list2.append(d)  
  
  for u in range(len(s_sentence)):
    if s_sentence[u] == "" and s_sentence[u+1] =="":
      first_line_end = u      
      break_early = True
      break 
  break_early = False 
    
  # 위원 아닌 출석 의원(X인)
  for e in range(len(s_sentence)):
    if e > m and e < first_line_end:
      ss_sentence += s_sentence[e].split("\n")      
  for a in range(len(ss_sentence)):    
    # 수정했는데 맞겠지?
    if (ss_sentence[a].startswith("◯") or ss_sentence[a].startswith("○")) and ss_sentence[a].endswith("인)"):      
      if ss_sentence[a].startswith("◯위원") or ss_sentence[a].startswith("○위원"):                
        b = a + 1        
        B_member = ss_sentence[b].split('  ')
        occup = "의원"
        break       
      else:
        b = a + 1
        B_member = ss_sentence[b].split('  ') 
        occup = "위원"
        break     
  for y in range(len(B_member)): 
    if B_member[y] not in p_name:
      name = B_member[y]
      d = {}      
      d['id'] = name
      # d['age'] = "NA"
      d['occupation'] = occup
      # d['sex'] = "NA"
      # d['birthplace'] = "NA"
      # d['principal_residence'] = "NA"
      # d['current_residence'] = "NA"
      # d['original_speaker_id'] = name 
      speaker_list2.append(d)
  # 위원 아닌 출석 의원(X인)2
  if ss_sentence[b+1].endswith("인)") == True:
    for e in range(len(s_sentence)):
      if e > m and e < first_line_end:
        ss_sentence += s_sentence[e].split("\n")      
    for a in range(len(ss_sentence)):    
      # 수정했는데 맞겠지?
      if (ss_sentence[a].startswith("◯") or ss_sentence[a].startswith("○")) and ss_sentence[a].endswith("인)"):      
        if ss_sentence[a].startswith("◯위원") or ss_sentence[a].startswith("○위원"):                
          b = a + 1        
          B_member = ss_sentence[b].split('  ')
          occup = "의원"
        else:
          b = a + 1
          B_member = ss_sentence[b].split('  ') 
          occup = "위원"
          
    for y in range(len(B_member)): 
      if B_member[y] not in p_name:
        name = B_member[y]
        d = {}      
        d['id'] = name
        # d['age'] = "NA"
        d['occupation'] = occup
        # d['sex'] = "NA"
        # d['birthplace'] = "NA"
        # d['principal_residence'] = "NA"
        # d['current_residence'] = "NA"
        # d['original_speaker_id'] = name 
        speaker_list2.append(d)
  
  # 출석 전문위원
  for a in range(len(ss_sentence)):    
    if not ss_sentence[a].endswith("인)") and (ss_sentence[a].startswith("◯") or ss_sentence[a].startswith("○")):
      s_start = a+1  
  for z in range(len(ss_sentence)):
    if z >= s_start:
      sss = ss_sentence[z].split("\n")
      sss_sentence += sss    
  count = int(len(sss_sentence) / 2)  
  id_s = range(count,len(sss_sentence))  
  ocu_s = range(0,count)
  for n, m in zip(id_s, ocu_s) :                
    if sss_sentence[n] not in p_name:        
      d = {}
      d['id'] = sss_sentence[n]
      # d['age'] = "NA"
      d['occupation'] = sss_sentence[m]
      # d['sex'] = "NA"
      # d['birthplace'] = "NA"
      # d['principal_residence'] = "NA"
      # d['current_residence'] = "NA"
      # d['original_speaker_id'] = sss_sentence[n] 
      speaker_list2.append(d) 
  
  try:  
    ## 위원 의원 아래 참석자      
    for p in range(len(s_sentence)):        
      if s_sentence[p].startswith("◯") and s_sentence[p].endswith("참석자"):      
        part = p + 1
        c = p + 2
        c_part = s_sentence[part]
        break  
    for l in range(len(s_sentence)):    
      if l >= part:      
        if s_sentence[l] == "" and s_sentence[l+1] =="":
          c_end = l
          break
        else:
          c_end = l + 1
    for m in range(len(s_sentence)):
      if m >= part and m < c_end:
        ssss = s_sentence[m].split('\n')      
        c_sentence += ssss
    count = int((len(c_sentence) -1) / 2) + 1  
    id_c = range(count, len(c_sentence))
    ocu_c = range(1,count)
    for n, m in zip(id_c, ocu_c) :                
      if c_sentence[n] not in p_name:        
        d = {}
        d['id'] = c_sentence[n]
        # d['age'] = "NA"
        d['occupation'] = c_part + c_sentence[m]
        # d['sex'] = "NA"
        # d['birthplace'] = "NA"
        # d['principal_residence'] = "NA"
        # d['current_residence'] = "NA"
        # d['original_speaker_id'] = c_sentence[n]
        speaker_list2.append(d)

  # 그다음꺼 있으면    
    if c_end != False:
      for h in range(len(s_sentence)):
        if h > c_end:
          if s_sentence[c_end] =="" and s_sentence[c_end+1] =="" and not s_sentence[c_end+2].startswith("◯"):          
            part2 = c_end +2
            d_part = s_sentence[part2]
            break
      if part2 != False:
        for r in range(len(s_sentence)):
          if r >= part2:
            if s_sentence[r] == "" and s_sentence[r+1] =="":
              d_end = r        
              break
            else:
              d_end = r + 1
      if part2 != False:
        for m in range(len(s_sentence)):
          if m >= part2 and m < d_end:
            sss = s_sentence[m].split('\n')      
            d_sentence += sss
        count = int((len(d_sentence) -1) / 2) + 1  
        id_d = range(count, len(d_sentence))
        ocu_d = range(1,count)
        for n, m in zip(id_d, ocu_d) :                
          if d_sentence[n] not in p_name:        
            d = {}
            d['id'] = d_sentence[n]
            # d['age'] = "NA"
            d['occupation'] = d_part + d_sentence[m]
            # d['sex'] = "NA"
            # d['birthplace'] = "NA"
            # d['principal_residence'] = "NA"
            # d['current_residence'] = "NA"
            # d['original_speaker_id'] = d_sentence[n]
            speaker_list2.append(d)     
  # 그다음꺼 있으면    2  
    if d_end != False:
      for h in range(len(s_sentence)):
        if h > d_end:
          if s_sentence[d_end] =="" and s_sentence[d_end+1] =="" and not s_sentence[d_end+2].startswith("◯"):          
            part3 = d_end +2
            e_part = s_sentence[part3]        
            break
      # print(part2)
      if part3 != False:
        for r in range(len(s_sentence)):
          if r >= part3:
            if s_sentence[r] == "" and s_sentence[r+1] =="":
              e_end = r        
              break
            else:
              e_end = r + 1
      if part3 != False:
        for m in range(len(s_sentence)):
          if m >= part3 and m < e_end:
            ssssss = s_sentence[m].split('\n')      
            e_sentence += ssssss
        # pprint(d_sentence)
        count = int((len(e_sentence) -1) / 2) + 1  
        id_e = range(count, len(e_sentence))
        ocu_e = range(1,count)
        for n, m in zip(id_e, ocu_e) :                
          if e_sentence[n] not in p_name:        
            d = {}
            d['id'] = e_sentence[n]
            # d['age'] = "NA"
            d['occupation'] = e_part + e_sentence[m]
            # d['sex'] = "NA"
            # d['birthplace'] = "NA"
            # d['principal_residence'] = "NA"
            # d['current_residence'] = "NA"
            # d['original_speaker_id'] = e_sentence[n]
            speaker_list2.append(d)
  # 그다음꺼 있으면   3
    if e_end != False:
      for h in range(len(s_sentence)):
        if h > e_end:
          if s_sentence[e_end] =="" and s_sentence[e_end+1] =="" and not s_sentence[e_end+2].startswith("◯"):          
            part4 = e_end +2
            f_part = s_sentence[part4]        
            break
      # print(part2)
      if part4 != False:
        for r in range(len(s_sentence)):
          if r >= part4:
            if s_sentence[r] == "" and s_sentence[r+1] =="":
              f_end = r        
              break
            else:
              f_end = r + 1
      if part4 != False:
        for m in range(len(s_sentence)):
          if m >= part4 and m < f_end:
            sssssss = s_sentence[m].split('\n')      
            f_sentence += sssssss
        # pprint(d_sentence)
        count = int((len(f_sentence) -1) / 2) + 1  
        id_f = range(count, len(f_sentence))
        ocu_f = range(1,count)
        for n, m in zip(id_f, ocu_f) :                
          if f_sentence[n] not in p_name:        
            d = {}
            d['id'] = f_sentence[n]
            # d['age'] = "NA"
            d['occupation'] = f_part + f_sentence[m]
            # d['sex'] = "NA"
            # d['birthplace'] = "NA"
            # d['principal_residence'] = "NA"
            # d['current_residence'] = "NA"
            # d['original_speaker_id'] = f_sentence[n]
            speaker_list2.append(d)
  # 그다음꺼 있으면 4
    if f_end != False:
      for h in range(len(s_sentence)):
        if h > f_end:
          if s_sentence[f_end] =="" and s_sentence[f_end+1] =="" and not s_sentence[f_end+2].startswith("◯"):          
            part5 = f_end +2
            g_part = s_sentence[part5]        
            break      
      if part5 != False:
        for r in range(len(s_sentence)):
          if r >= part5:
            if s_sentence[r] == "" and s_sentence[r+1] =="":
              g_end = r        
              break
            else:
              g_end = r + 1
      if part5 != False:
        for m in range(len(s_sentence)):
          if m >= part5 and m < g_end:
            ssssssss = s_sentence[m].split('\n')      
            g_sentence += ssssssss
        # pprint(d_sentence)
        count = int((len(f_sentence) -1) / 2) + 1  
        id_g = range(count, len(f_sentence))
        ocu_g = range(1,count)
        for n, m in zip(id_g, ocu_g) :                
          if g_sentence[n] not in p_name:        
            d = {}
            d['id'] = g_sentence[n]
            # d['age'] = "NA"
            d['occupation'] = g_part + g_sentence[m]
            # d['sex'] = "NA"
            # d['birthplace'] = "NA"
            # d['principal_residence'] = "NA"
            # d['current_residence'] = "NA"
            # d['original_speaker_id'] = f_sentence[n]
            speaker_list2.append(d)              
      # print("except")
    # 진술인 참고인 
    for f in range(len(s_sentence)):
      if s_sentence[f].startswith("◯") and s_sentence[f].endswith("참고인"):
        role = s_sentence[f].split(" ")[1]            
        ss_start = f + 1         
    if ss_start != False:
      # print(s_start)
      for j in range(len(s_sentence)):
        if j >= ss_start:
          ee = s_sentence[j].split("(")
          eee = ee[0].split('\n')
          e_sentence += eee      
      for n in range(len(e_sentence)) :                
        if e_sentence[n] not in p_name:        
          d = {}
          d['id'] = e_sentence[n]
          # d['age'] = "NA"
          d['occupation'] = role  
          # d['sex'] = "NA"
          # d['birthplace'] = "NA"
          # d['principal_residence'] = "NA"
          # d['current_residence'] = "NA"
          # d['original_speaker_id'] = e_sentence[n]
          speaker_list2.append(d)    
    # print(p_name)    
  except:
    print("except")
    # 진술인 참고인 
    for f in range(len(s_sentence)):
      if s_sentence[f].startswith("◯") and (s_sentence[f].endswith("참고인") or s_sentence[f].endswith("진술인")):
        role = s_sentence[f].split(" ")[1]            
        ss_start = f + 1         
    if ss_start != False:
      # print(s_start)
      for j in range(len(s_sentence)):
        if j >= ss_start:
          ee = s_sentence[j].split("(")
          eee = ee[0].split('\n')
          e_sentence += eee      
      for n in range(len(e_sentence)) :                
        if e_sentence[n] not in p_name:        
          d = {}
          d['id'] = e_sentence[n]
          # d['age'] = "NA"
          d['occupation'] = role  
          # d['sex'] = "NA"
          # d['birthplace'] = "NA"
          # d['principal_residence'] = "NA"
          # d['current_residence'] = "NA"
          # d['original_speaker_id'] = e_sentence[n]
          speaker_list2.append(d)    
    # print(p_name)
  finally:
    for last in range(len(speaker_list2)):
      if speaker_list2[last]['id'] not in p2_name:
        d = {}
        d['id'] = speaker_list2[last]['id']
        # d['age'] = "NA"
        d['occupation'] = speaker_list2[last]['occupation']
        # d['sex'] = "NA"
        # d['birthplace'] = "NA"
        # d['principal_residence'] = "NA"
        # d['current_residence'] = "NA"
        # d['original_speaker_id'] = speaker_list2[last]['id']  
        speaker_list2__2.append(d)     
  return speaker_list2__2
speaker_list2__2 = speaker_extractor2_or(text,speaker_list, speaker_list__, speaker_ex)
pprint(speaker_list2__2)
# Out:
# [{'id': '강석호', 'occupation': '위원'},
#  {'id': '민홍철', 'occupation': '위원'},
#  {'id': '안효대', 'occupation': '위원'},
#  {'id': '윤후덕', 'occupation': '위원'},
#  {'id': '김요환', 'occupation': '전문위원'},
#  {'id': '여형구', 'occupation': '국토교통부제2차관'},
#  {'id': '김경욱', 'occupation': '국토교통부철도국장'},
#  {'id': '한문희', 'occupation': '국토교통부한국철도공사경영지원본부장'}]

# %%
# json 형태로 변환하기 위한 틀
def convert_to_korea(meta, speaker_list,speaker_list__, speaker_list2__2, dialog_json, id):
    # k = 0
    id = "SBRW 2100000001"
    # id_code = korea_formatted_data['id']
    # id = id_code.split(" ")
    # id0 = id[0]
    # id1 = int(id[1]) + k
    # id = id0 + str(id1)
    # korea_formatted_data['id'] = id    
    # k += 1

    metadata = {}
    metadata['title'] = "국립국어원 국회 회의록 원시 말뭉치 " + id
    metadata['creator'] = "국립국어원"
    metadata['distributor'] = "국립국어원"
    metadata['year'] = "2021"
    metadata['category'] = meta['카테고리']
    metadata['annotation_level'] = ['원시']
    metadata['sampling'] = "본문 전체"
        
    doc = {}
    doc['id'] = id+".1"
    doc_metadata = {}
    doc_metadata['title'] = meta['회의록제목']
    doc_metadata['author'] = meta['작성']
    # doc_metadata['author_id'] = "" 
    doc_metadata['publisher'] = meta['작성']
    doc_metadata['date'] = meta['일시']
    doc_metadata['topic'] = meta['토픽']    
    # doc_metadata['original_topic'] = ""
    # doc_metadata['crawl_date'] = ""

    doc_metadata['speaker'] = speaker_list__ + speaker_list2__2    
    pprint(meta['회의록제목'])
    pprint(meta['일시'])
    pprint(doc_metadata['speaker'])
    # doc_metadata['setting'] = {}
    # doc_metadata['setting']['relation'] = "NA"
    
    # doc_metadata['file_id'] = meta['파일명']
      # '회의록 원문 자료 파일명:'

    doc['metadata'] = doc_metadata
    
    # doc['paragraph'] = []
    # paragraph = {}
    # paragraph['id'] = ""
    # paragraph['form'] = ""
    # paragraph['original_form'] = ""
    # doc['paragraph'].append(paragraph)
    
    utterance = []
    
    n = 0
    for i in dialog_json:
        utter = {}
        utter['id'] = id+".1.1."+ str(n+1)
        utter['form'] = i['utterance'].rstrip()
        utter['original_form'] = i['utterance_or'].rstrip()
        utter['speaker_id'] = i['speaker']
        # utter['note'] = ""
        utterance.append(utter)
        n += 1
        # pprint(utter['id'])   
    doc['utterance'] = utterance
    
    d = {}
    d['id'] = id
    d['metadata'] = metadata
    d['document'] = doc
    
    return d
korea_formatted_data = convert_to_korea(meta, speaker_list,speaker_list__, speaker_list2__2, dialog_json, id)
# pprint(korea_formatted_data)
# pprint(korea_formatted_data['document']['utterance'][0])
# Out:
# ' 제323회국회(임시회) 국토교통위원회회의록(철도산업발전소위원회) 제2호'
# '20140410'
# [{'id': '강석호', 'occupation': '소위원장'},
#  {'id': '김요환', 'occupation': '전문위원'},
#  {'id': '여형구', 'occupation': '국토교통부제2차관'},
#  {'id': '윤후덕', 'occupation': '위원'},
#  {'id': '민홍철', 'occupation': '위원'},
#  {'id': '안효대', 'occupation': '위원'},
#  {'id': '한문희', 'occupation': '한국철도공사경영지원본부장'},
#  {'id': '김경욱', 'occupation': '국토교통부철도국장'}]

# %%
# json 형태로 변환
def txt_reader(id):
  k = 0
  files = sorted(glob('/content/drive/My Drive/Colab Notebooks/task/Minutes(Korean)/회의록 2차/*.txt'))  
  for fname in files:
    with open(fname, 'r', encoding='utf-8-sig') as file:
      txt = file.readlines()      
      pass
      text = clean_up(txt)      
      text_or = clean_up_or(txt)
      pm_date = date_extractor(text)      
      pm_author = author(text)      
      pm_topic = topic_extractor(text)      
      meta = meta_extractor(text, pm_date, pm_topic, pm_author, fname)      
      dialog = dialog_extractor(text)      
      dialog_or = dialog_extractor_or(text_or)      
      speaker_ex = speaker_extractor(dialog)
      speaker_ex_or = speaker_extractor_or(dialog_or)      
      utterance_ex = utterance_extractor(dialog)       
      utterance_ex_or = utterance_extractor_or(dialog_or)         
      dialog_json = dialog_formatting(utterance_ex, utterance_ex_or)  
      speaker_list = speaker_list_extractor(speaker_ex,speaker_ex_or)              
      speaker_list__ = speaker_list_extractor_or(speaker_ex,speaker_ex_or)      
      speaker_list2__2 = speaker_extractor2_or(text,speaker_list, speaker_list__, speaker_ex)     
      korea_formatted_data = convert_to_korea(meta, speaker_list, speaker_list__, speaker_list2__2, dialog_json, id)     
      id = "SBRW 2100000001"
      id_code = id.split(" ")
      id0 = id_code[0]
      id1 = int(id_code[1]) + k
      id_code = id0 + str(id1)
      korea_formatted_data['id'] = id_code
      korea_formatted_data['metadata']['title'] = "국립국어원 국회 회의록 원시 말뭉치 " + id_code
      korea_formatted_data['document']['id'] = id_code + ".1"
      # print(korea_formatted_data)
      n = 0
      for i in dialog_json:
        korea_formatted_data['document']['utterance'][n]['id'] = id_code+".1.1."+ str(n+1)
        n += 1
      k += 1     
    # fname_write = fname.split('/')[-1].split('.txt')[0]    
      
    with open('/content/drive/My Drive/Colab Notebooks/task/Minutes(Korean)/회의록 2차 json/'+id_code+'.json', 'w') as f:
      json.dump(korea_formatted_data, f, ensure_ascii=False, indent=4)
    
    # /content/drive/My Drive/Colab Notebooks/task/Minutes(Korean)/(jw)pm_summary_preprocessor/

txt_reader(id)
# txt_reader(fname)
# Out:
# ' 제311회국회(정기회) 교육과학기술위원회회의록(법안심사소위원회) 제3호'
# '20120924'
# [{'id': '金世淵', 'occupation': '소위원장'},
#  {'id': '김태년', 'occupation': '위원'},
#  {'id': '조율래', 'occupation': '교육과학기술부제2차관'},
#  {'id': '유기홍', 'occupation': '위원'},
#  {'id': '임진대', 'occupation': '전문위원'},
#  {'id': '이상민', 'occupation': '위원'},
#  {'id': '박혜자', 'occupation': '위원'},
#  {'id': '이진규', 'occupation': '교육과학기술부창의인재정책관'},
#  {'id': '강은희', 'occupation': '위원'},
#  {'id': '민병주', 'occupation': '위원'},
#  {'id': '정진후', 'occupation': '위원'},
#  {'id': '徐相箕', 'occupation': '위원'},
#  {'id': '송기동', 'occupation': '교육과학기술부대학지원관'},
#  {'id': '박인숙', 'occupation': '위원'},
#  {'id': '노재석', 'occupation': '수석전문위원'},
#  {'id': '김관복', 'occupation': '교육과학기술부인재정책실장'},
#  {'id': '정종철', 'occupation': '교육과학기술부미래인재정책관'},
#  {'id': '이용원', 'occupation': '전문위원'},
#  {'id': '구자문', 'occupation': '대학지원실장'}]
# ' 제311회국회(정기회) 국토해양위원회회의록(예산결산기금심사소위원회) 제2호'
# '20121107'
# [{'id': '이윤석', 'occupation': '소위원장'},
#  {'id': '허태수', 'occupation': '전문위원'},
#  {'id': '김태흠', 'occupation': '위원'},
#  {'id': '한만희', 'occupation': '국토해양부제1차관'},
#  {'id': '신기남', 'occupation': '위원'},
#  {'id': '신장용', 'occupation': '위원'},
#  {'id': '변재일', 'occupation': '위원'},
#  {'id': '구본환', 'occupation': '국토해양부철도정책관'},
#  {'id': '이이재', 'occupation': '위원'},
#  {'id': '李憲昇', 'occupation': '위원'},
#  {'id': '이종진', 'occupation': '위원'},
#  {'id': '박상은', 'occupation': '위원'},
#  {'id': '여형구', 'occupation': '국토해양부항공정책실장'},
#  {'id': '박수철', 'occupation': '전문위원'},
#  {'id': '연영진', 'occupation': '국토해양부해양정책국장'},
#  {'id': '김석균', 'occupation': '해양경찰청차장'}]
# ' 제311회국회(정기회) 법제사법위원회회의록(예산결산심사소위원회) 제3호'
# '20121121'
# [{'id': '권성동', 'occupation': '소위원장'},
#  {'id': '이한규', 'occupation': '수석전문위원'},
#  {'id': '길태기', 'occupation': '법무부차관'},
#  {'id': '이춘석', 'occupation': '위원'},
#  {'id': '국민수', 'occupation': '법무부검찰국장'},
#  {'id': '김주현', 'occupation': '법무부기획조정실장'},
#  {'id': '서영교', 'occupation': '위원'},
#  {'id': '김도읍', 'occupation': '위원'},
#  {'id': '이한규', 'occupation': '수서전문위원'},
#  {'id': '서기호', 'occupation': '위원'},
#  {'id': '강찬우', 'occupation': '법무연수원기획부장'},
#  {'id': '권정훈', 'occupation': '법무부검찰과장'},
#  {'id': '황윤성', 'occupation': '법무부법무실장'},
#  {'id': '이건주', 'occupation': '법무부범죄예방정책국장'},
#  {'id': '봉욱', 'occupation': '법무부인권국장'},
#  {'id': '이상용', 'occupation': '전문위원'},
#  {'id': '전상수', 'occupation': '전문위원'},
#  {'id': '문광섭', 'occupation': '전문위원'}]
# ' 제311회국회(정기회) 법제사법위원회회의록(예산결산심사소위원회) 제4호'
# '20121203'
# [{'id': '권성동', 'occupation': '소위원장'},
#  {'id': '전상수', 'occupation': '전문위원'},
#  {'id': '이춘석', 'occupation': '위원'},
#  {'id': '길태기', 'occupation': '법무부차관'},
#  {'id': '국민수', 'occupation': '법무부검찰국장'},
#  {'id': '서영교', 'occupation': '위원'},
#  {'id': '박범계', 'occupation': '위원'},
#  {'id': '문권점', 'occupation': '법무부기획재정담당관'},
#  {'id': '서기호', 'occupation': '위원'},
#  {'id': '이창세', 'occupation': '법무부출입국·외국인정책본부장'},
#  {'id': '황윤성', 'occupation': '법무부법무실장'},
#  {'id': '권정훈', 'occupation': '법무부검찰과장'},
#  {'id': '김동환', 'occupation': '법무부복지과'},
#  {'id': '봉욱', 'occupation': '법무부인권국장'},
#  {'id': '이건주', 'occupation': '법무부범죄예방정책국장'},
#  {'id': '노철래', 'occupation': '위원'},
#  {'id': '문광섭', 'occupation': '전문위원'}]
# ' 제311회국회(정기회) 외교통상통일위원회회의록(법안심사소위원회) 제3호'
# '20121119'
# [{'id': '정문헌', 'occupation': '소위원장'},
#  {'id': '성석호', 'occupation': '수석전문위원'},
#  {'id': '안호영', 'occupation': '외교통상부제1차관'},
#  {'id': '심재권', 'occupation': '위원'},
#  {'id': '최동규', 'occupation': '외교통상부FTA정책국장'},
#  {'id': '홍익표', 'occupation': '위원'},
#  {'id': '정청래', 'occupation': '위원'},
#  {'id': '백지아', 'occupation': '외교통상부국제기구국장'},
#  {'id': '심윤조', 'occupation': '위원'},
#  {'id': '한동만', 'occupation': '외교통상부국제경제국장'},
#  {'id': '배용근', 'occupation': '전문위원'},
#  {'id': '조대식', 'occupation': '외교통상부기획조정실장'}]
# ' 제311회국회(정기회) 기획재정위원회회의록(경제재정소위원회) 제3호'
# '20120924'
# [{'id': '김현미', 'occupation': '소위원장'},
#  {'id': '국경복', 'occupation': '수석전문위원'},
#  {'id': '홍동호', 'occupation': '기획재정부정책조정관리관'},
#  {'id': '정두언', 'occupation': '위원'},
#  {'id': '신형철', 'occupation': '기획재정부국고국장'},
#  {'id': '윤호중', 'occupation': '위원'},
#  {'id': '김재신', 'occupation': '기획재정부계약제도과장'},
#  {'id': '남병덕', 'occupation': '조달청품질관리단장'},
#  {'id': '이인영', 'occupation': '위원'},
#  {'id': '방문규', 'occupation': '기획재정부예산총괄심의관'},
#  {'id': '설훈', 'occupation': '위원'},
#  {'id': '이재영', 'occupation': '위원'}]
# ' 제311회국회(정기회) 기획재정위원회회의록(예산결산기금심사소위원회) 제3호'
# '20121106'
# [{'id': '이한성', 'occupation': '소위원장'},
#  {'id': '안민석', 'occupation': '위원'},
#  {'id': '국경복', 'occupation': '수석전문위원'},
#  {'id': '김형광', 'occupation': '복권위원회사무처기금사업과장'},
#  {'id': '신형철', 'occupation': '기획재정부국고국장'},
#  {'id': '홍종학', 'occupation': '위원'},
#  {'id': '신제윤', 'occupation': '기획재정부제1차관'},
#  {'id': '金光琳', 'occupation': '위원'},
#  {'id': '류성걸', 'occupation': '위원'},
#  {'id': '김재연', 'occupation': '위원'},
#  {'id': '권성모', 'occupation': '기획재정부기금운용계획과'},
#  {'id': '김규옥', 'occupation': '기획재정부기획조정실장'}]
# ' 제311회국회(정기회) 기획재정위원회회의록(예산결산기금심사소위원회) 제8호'
# '20121115'
# [{'id': '이한성', 'occupation': '소위원장'},
#  {'id': '국경복', 'occupation': '수석전문위원'},
#  {'id': '金光琳', 'occupation': '위원'},
#  {'id': '류성걸', 'occupation': '위원'},
#  {'id': '홍종학', 'occupation': '위원'},
#  {'id': '신제윤', 'occupation': '기획재정부제1차관'},
#  {'id': '김재연', 'occupation': '위원'},
#  {'id': '신형철', 'occupation': '기획재정부국고국장'},
#  {'id': '이인옥', 'occupation': '기획재정부경제교육홍보팀장'},
#  {'id': '안민석', 'occupation': '위원'},
#  {'id': '성창훈', 'occupation': '기획재정부물가정책과장'},
#  {'id': '김규옥', 'occupation': '기획재정부기획조정실장'},
#  {'id': '이승원', 'occupation': '기획재정부개발협력과장'},
#  {'id': '김형광', 'occupation': '복권위원회사무처기금사업과장'},
#  {'id': '박주성', 'occupation': '법무부검찰과예산검사'},
#  {'id': '정인권', 'occupation': '기획재정부국유재산조정과장'},
#  {'id': '송대호', 'occupation': '전문위원'}]
# except
# ' 제311회국회(정기회) 기획재정위원회회의록(예산결산기금심사소위원회) 제9호'
# '20121120'
# [{'id': '이한성', 'occupation': '소위원장'},
#  {'id': '국경복', 'occupation': '수석전문위원'},
#  {'id': '신제윤', 'occupation': '기획재정부제1차관'},
#  {'id': '金光琳', 'occupation': '위원'},
#  {'id': '김규옥', 'occupation': '기획재정부기획조정실장'},
#  {'id': '류성걸', 'occupation': '위원'},
#  {'id': '권광호', 'occupation': '한국장학재단상임이사'},
#  {'id': '오근창', 'occupation': '한국장학재단여신기획팀장'},
#  {'id': '홍종학', 'occupation': '위원'},
#  {'id': '신형철', 'occupation': '기획재정부국고국장'},
#  {'id': '박윤준', 'occupation': '국세청차장'},
#  {'id': '나동균', 'occupation': '국세청기획조정관'},
#  {'id': '김철수', 'occupation': '국세청관세청차장'},
#  {'id': '민형종', 'occupation': '조달청차장'},
#  {'id': '구자현', 'occupation': '조달청기획조정관'},
#  {'id': '제정본', 'occupation': '통계청차장'},
#  {'id': '이상율', 'occupation': '통계청기획조정관'}]
# ' 제311회국회(정기회) 행정안전위원회회의록(법안심사소위원회) 제2호'
# '20120919'
# [{'id': '고희선', 'occupation': '소위원장'},
#  {'id': '문강주', 'occupation': '전문위원'},
#  {'id': '김용희', 'occupation': '중앙선거관리위원회선거실장'},
#  {'id': '김민기', 'occupation': '위원'},
#  {'id': '백재현', 'occupation': '위원'},
#  {'id': '金永柱', 'occupation': '위원'},
#  {'id': '유대운', 'occupation': '위원'},
#  {'id': '박성효', 'occupation': '위원'},
#  {'id': '유승우', 'occupation': '위원'},
#  {'id': '김정석', 'occupation': '경찰청차장'},
#  {'id': '윤재옥', 'occupation': '위원'},
#  {'id': '이원탁', 'occupation': '수석전문위원'},
#  {'id': '최동해', 'occupation': '경찰청기획조정관'}]
# ' 제313회국회(임시회) 문화체육관광방송통신위원회회의록(법안심사소위원회) 제1호'
# '20130215'
# [{'id': '조해진', 'occupation': '소위원장'},
#  {'id': '이인용', 'occupation': '수석전문위원'},
#  {'id': '김충식', 'occupation': '방송통신위원회부위원장'},
#  {'id': '김대희', 'occupation': '방송통신위원회상임위원'},
#  {'id': '홍지만', 'occupation': '위원'},
#  {'id': '최재천', 'occupation': '위원'},
#  {'id': '박대출', 'occupation': '위원'},
#  {'id': '장병완', 'occupation': '위원'},
#  {'id': '남경필', 'occupation': '위원'},
#  {'id': '유승희', 'occupation': '위원'},
#  {'id': '김기현', 'occupation': '위원'},
#  {'id': '노웅래', 'occupation': '위원'},
#  {'id': '전병헌', 'occupation': '위원'},
#  {'id': '곽영진', 'occupation': '문화체육관광부제1차관'},
#  {'id': '박순태', 'occupation': '문화체육관광부문화콘텐츠산업실장'},
#  {'id': '백화종', 'occupation': '게임물등급위원장'},
#  {'id': '김한근', 'occupation': '전문위원'},
#  {'id': '최재유', 'occupation': '방송통신위원회기획조정실장'}]
# ' 제315회국회(임시회) 국방위원회회의록(예산결산심사소위원회) 제1호'
# '20130423'
# [{'id': '한기호', 'occupation': '소위원장'},
#  {'id': '백승주', 'occupation': '국방부차관'},
#  {'id': '권기율', 'occupation': '수석전문위원'},
#  {'id': '정희수', 'occupation': '위원'},
#  {'id': '진성준', 'occupation': '위원'},
#  {'id': '황희종', 'occupation': '국방부군사시설기획관'},
#  {'id': '백군기', 'occupation': '위원'},
#  {'id': '안수현', 'occupation': '국방부건설관리과장'},
#  {'id': '김재윤', 'occupation': '위원'},
#  {'id': '김성찬', 'occupation': '위원'},
#  {'id': '김종태', 'occupation': '위원'},
#  {'id': '안상훈', 'occupation': '국방시설본부건설사업처장'},
#  {'id': '김형태', 'occupation': '위원'},
#  {'id': '곽종구', 'occupation': '육군제1야전군사령부통합화력운용과'},
#  {'id': '김진표', 'occupation': '위원'},
#  {'id': '이정수', 'occupation': '서북도서방위사령부화력처장'},
#  {'id': '이정수', 'occupation': '서북도서방위사령부화력처장장'},
#  {'id': '김광우', 'occupation': '국방부기획조정실장'},
#  {'id': '오태식', 'occupation': '방위사업청사업관리본부장'},
#  {'id': '김윤석', 'occupation': '국방부계획예산관'},
#  {'id': '구병회', 'occupation': '전문위원'},
#  {'id': '김성준', 'occupation': '국방부예산편성담당관'},
#  {'id': '이상욱', 'occupation': '국방부군수관리관'},
#  {'id': '염현덕', 'occupation': '육군본부화생방담당관'},
#  {'id': '홍두표', 'occupation': '방위사업청기동화력사업부장'},
#  {'id': '황성환', 'occupation': '방위사업청유도무기사업부장'},
#  {'id': '김태곤', 'occupation': '방위사업청재정정보화기획관직무대리'}]
# ' 제315회국회(임시회) 국토교통위원회회의록(교통법안심사소위원회) 제1호'
# '20130423'
# [{'id': '박기춘', 'occupation': '소위원장'},
#  {'id': '김요환', 'occupation': '전문위원'},
#  {'id': '여형구', 'occupation': '국토교통부제2차관'},
#  {'id': '조현룡', 'occupation': '위원'},
#  {'id': '손영삼', 'occupation': '국토교통부자동차운영과'},
#  {'id': '이철우', 'occupation': '위원'},
#  {'id': '주승용', 'occupation': '위원장'},
#  {'id': '김수곤', 'occupation': '국토교통부물류정책관'},
#  {'id': '이장우', 'occupation': '위원'},
#  {'id': '문병호', 'occupation': '위원'},
#  {'id': '李憲昇', 'occupation': '위원'},
#  {'id': '민홍철', 'occupation': '위원'},
#  {'id': '박종흠', 'occupation': '국토교통부교통물류실장'},
#  {'id': '서삼호', 'occupation': '국토교통부항공보안과'},
#  {'id': '최정호', 'occupation': '국토교통부항공정책실장'},
#  {'id': '박수현', 'occupation': '위원'},
#  {'id': '윤진식', 'occupation': '위원'}]
# ' 제315회국회(임시회) 여성가족위원회회의록(유엔여성차별철폐협약이행정책심사소위원회) 제1호'
# '20130423'
# [{'id': '류지영', 'occupation': '소위원장'},
#  {'id': '이복실', 'occupation': '여성가족부차관'},
#  {'id': '성삼제', 'occupation': '교육부기획조정실장'},
#  {'id': '봉욱', 'occupation': '법무부기획조정실장'},
#  {'id': '최희주', 'occupation': '보건복지부인구정책실장'},
#  {'id': '전정희', 'occupation': '위원'},
#  {'id': '신경림', 'occupation': '위원'},
#  {'id': '홍현주', 'occupation': '여성가족부국제협력담당관'},
#  {'id': '이용원', 'occupation': '수석전문위원'},
#  {'id': '이주원', 'occupation': '외교부인권사회과'},
#  {'id': '최승묵', 'occupation': '농림축산식품부농촌사회과'},
#  {'id': '남인순', 'occupation': '위원'},
#  {'id': '길정우', 'occupation': '위원'},
#  {'id': '차인순', 'occupation': '입법심의관'}]
# ' 제315회국회(임시회) 기획재정위원회회의록(예산결산기금심사소위원회) 제3호'
# '20130503'
# [{'id': '이한성', 'occupation': '소위원장'},
#  {'id': '류환민', 'occupation': '수석전문위원'},
#  {'id': '추경호', 'occupation': '기획재정부제1차관'},
#  {'id': '설훈', 'occupation': '위원'},
#  {'id': '김재연', 'occupation': '위원'},
#  {'id': '김상수', 'occupation': '입법조사관'},
#  {'id': '류성걸', 'occupation': '위원'},
#  {'id': '김낙회', 'occupation': '기획재정부세제실장'},
#  {'id': '김세훈', 'occupation': '관세청기획재정담당관실'},
#  {'id': '구병성', 'occupation': '입법조사관'},
#  {'id': '송대호', 'occupation': '전문위원'},
#  {'id': '최원목', 'occupation': '기획재정부기획조정실장'}]
# ' 제315회국회(임시회) 기획재정위원회회의록(조세소위원회) 제2호'
# '20130418'
# [{'id': '나성린', 'occupation': '소위원장'},
#  {'id': '김낙회', 'occupation': '기획재정부세제실장'},
#  {'id': '송대호', 'occupation': '전문위원'},
#  {'id': '이석준', 'occupation': '기획재정부제2차관'},
#  {'id': '金光琳', 'occupation': '위원'},
#  {'id': '박원석', 'occupation': '위원'},
#  {'id': '조정식', 'occupation': '위원'},
#  {'id': '류성걸', 'occupation': '위원'},
#  {'id': '홍종학', 'occupation': '위원'},
#  {'id': '문창용', 'occupation': '기획재정부재산소비세정책관'},
#  {'id': '박정용', 'occupation': '입법조사관'},
#  {'id': '정성호', 'occupation': '위원'},
#  {'id': '최경환', 'occupation': '위원'},
#  {'id': '나동균', 'occupation': '국세청기획조정관'},
#  {'id': '이만우', 'occupation': '위원'},
#  {'id': '진선희', 'occupation': '입법조사관'}]
# ' 제315회국회(임시회) 기획재정위원회회의록(조세개혁소위원회) 제1호'
# '20130424'
# [{'id': '조정식', 'occupation': '소위원장'},
#  {'id': '나성린', 'occupation': '위원'},
#  {'id': '박원석', 'occupation': '위원'},
#  {'id': '안종범', 'occupation': '위원'},
#  {'id': '진선희', 'occupation': '입법조사관'},
#  {'id': '류성걸', 'occupation': '위원'},
#  {'id': '홍종학', 'occupation': '위원'},
#  {'id': '이인영', 'occupation': '위원'},
#  {'id': '이석준', 'occupation': '기획재정부제2차관'},
#  {'id': '김낙회', 'occupation': '기획재정부세제실장'},
#  {'id': '송대호', 'occupation': '전문위원'}]
# except
# ' 제315회국회(임시회) 환경노동위원회회의록(법안심사소위원회) 제2호'
# '20130417'
# [{'id': '김성태', 'occupation': '소위원장'},
#  {'id': '박종갑', 'occupation': '진술인'},
#  {'id': '한지혜', 'occupation': '진술인'},
#  {'id': '이민희', 'occupation': '진술인'},
#  {'id': '노길준', 'occupation': '진술인'},
#  {'id': '이종훈', 'occupation': '위원'},
#  {'id': '최봉홍', 'occupation': '위원'},
#  {'id': '고인석', 'occupation': '진술인'},
#  {'id': '은수미', 'occupation': '위원'},
#  {'id': '홍영표', 'occupation': '위원'},
#  {'id': '심상정', 'occupation': '위원'},
#  {'id': '이완영', 'occupation': '위원'},
#  {'id': '한정애', 'occupation': '위원'},
#  {'id': '한공식', 'occupation': '수석전문위원'},
#  {'id': '김양건', 'occupation': '전문위원'}]
# ' 제316회국회(임시회) 교육문화체육관광위원회회의록(법안심사소위원회) 제1호'
# '20130624'
# [{'id': '김희정', 'occupation': '소위원장'},
#  {'id': '박인숙', 'occupation': '위원'},
#  {'id': '이용섭', 'occupation': '위원'},
#  {'id': '윤관석', 'occupation': '위원'},
#  {'id': '유기홍', 'occupation': '위원'},
#  {'id': '임진대', 'occupation': '수석전문위원'},
#  {'id': '박백범', 'occupation': '교육부대학지원실장'},
#  {'id': '유은혜', 'occupation': '위원'},
#  {'id': '김장실', 'occupation': '위원'},
#  {'id': '나승일', 'occupation': '교육부차관'},
#  {'id': '서유미', 'occupation': '교육부학술장학지원관'},
#  {'id': '강은희', 'occupation': '위원'},
#  {'id': '도종환', 'occupation': '위원'},
#  {'id': '정병걸', 'occupation': '교육부지방교육지원국장'},
#  {'id': '이에리사', 'occupation': '위원'},
#  {'id': '박명수', 'occupation': '전문위원'}]
# ' 제316회국회(임시회) 국방위원회회의록(국방운영개선소위원회) 제1호'
# '20130604'
# [{'id': '김진표', 'occupation': '소위원장'},
#  {'id': '황인무', 'occupation': '육군참모차장'},
#  {'id': '박대섭', 'occupation': '국방부인사복지실장'},
#  {'id': '류성식', 'occupation': '육군본부인사참모부장'},
#  {'id': '김형태', 'occupation': '위원'},
#  {'id': '진성준', 'occupation': '위원'},
#  {'id': '김성찬', 'occupation': '위원'},
#  {'id': '김흥석', 'occupation': '육군본부법무실장'},
#  {'id': '송영근', 'occupation': '위원'},
#  {'id': '신경식', 'occupation': '육군사관학교교수부장'},
#  {'id': '정희수', 'occupation': '위원'},
#  {'id': '김광진', 'occupation': '위원'},
#  {'id': '권기율', 'occupation': '수석전문위원'}]
# ' 제316회국회(임시회) 법제사법위원회회의록(법안심사제1소위원회) 제4호'
# '20130628'
# [{'id': '권성동', 'occupation': '소위원장'},
#  {'id': '문광섭', 'occupation': '전문위원'},
#  {'id': '이춘석', 'occupation': '위원'},
#  {'id': '전해철', 'occupation': '위원'},
#  {'id': '서기호', 'occupation': '위원'},
#  {'id': '박범계', 'occupation': '위원'},
#  {'id': '김재정', 'occupation': '국토교통부주택정책관'},
#  {'id': '국민수', 'occupation': '법무부차관'},
#  {'id': '권순일', 'occupation': '법원행정처차장'},
#  {'id': '장영섭', 'occupation': '법무부법무심의관'},
#  {'id': '김회선', 'occupation': '위원'},
#  {'id': '국민수', 'occupation': '법무부장관'},
#  {'id': '정재룡', 'occupation': '전문위원'},
#  {'id': '임종헌', 'occupation': '법원행정처기획조정실장'},
#  {'id': '임중호', 'occupation': '수석전문위원'},
#  {'id': '이상용', 'occupation': '전문위원'}]
# ' 제316회국회(임시회) 법제사법위원회회의록(법안심사제2소위원회) 제2호'
# '20130628'
# [{'id': '이춘석', 'occupation': '소위원장'},
#  {'id': '임중호', 'occupation': '수석전문위원'},
#  {'id': '이경옥', 'occupation': '안전행정부제2차관'},
#  {'id': '김진태', 'occupation': '위원'},
#  {'id': '김회선', 'occupation': '위원'},
#  {'id': '노철래', 'occupation': '위원'},
#  {'id': '김학용', 'occupation': '위원'},
#  {'id': '이상용', 'occupation': '전문위원'},
#  {'id': '전해철', 'occupation': '위원'},
#  {'id': '박범계', 'occupation': '위원'},
#  {'id': '정연만', 'occupation': '환경부차관'},
#  {'id': '김재정', 'occupation': '국토교통부주택정책관'},
#  {'id': '권성동', 'occupation': '위원'},
#  {'id': '박기풍', 'occupation': '국토교통부제1차관'},
#  {'id': '문광섭', 'occupation': '전문위원'},
#  {'id': '이영찬', 'occupation': '보건복지부차관'},
#  {'id': '장병원', 'occupation': '식품의약품안전처차장'},
#  {'id': '서영교', 'occupation': '위원'},
#  {'id': '정재룡', 'occupation': '전문위원'},
#  {'id': '김남식', 'occupation': '통일부차관'},
#  {'id': '나승일', 'occupation': '교육부차관'},
#  {'id': '류순현', 'occupation': '안전행정부지방행정정책관'},
#  {'id': '박춘란', 'occupation': '교육부대학정책관'},
#  {'id': '한진현', 'occupation': '산업통상자원부제2차관'},
#  {'id': '신경민', 'occupation': '위원'}]
# ' 제316회국회(임시회) 환경노동위원회회의록(법안심사소위원회) 제1호'
# '20130620'
# [{'id': '김성태', 'occupation': '소위원장'},
#  {'id': '홍영표', 'occupation': '위원'},
#  {'id': '이완영', 'occupation': '위원'},
#  {'id': '은수미', 'occupation': '위원'},
#  {'id': '김양건', 'occupation': '전문위원'},
#  {'id': '한정애', 'occupation': '위원'},
#  {'id': '심상정', 'occupation': '위원'},
#  {'id': '이종훈', 'occupation': '위원'},
#  {'id': '최봉홍', 'occupation': '위원'},
#  {'id': '정현옥', 'occupation': '고용노동부차관'},
#  {'id': '임서정', 'occupation': '고용노동부노동시장정책관'},
#  {'id': '한공식', 'occupation': '수석전문위원'},
#  {'id': '나영돈', 'occupation': '고용노동부직업능력정책관'},
#  {'id': '이수영', 'occupation': '고용노동부고령사회인력심의관'},
#  {'id': '임무송', 'occupation': '고용노동부근로개선정책관'}]
# ' 제317회국회(임시회) 여성가족위원회회의록(일본군위안부문제대책소위원회) 제1호'
# '20130712'
# [{'id': '길정우', 'occupation': '소위원장'},
#  {'id': '김규현', 'occupation': '외교부제1차관'},
#  {'id': '이복실', 'occupation': '여성가족부차관'},
#  {'id': '이상덕', 'occupation': '외교부동북아시아국심의관'},
#  {'id': '김현숙', 'occupation': '위원'},
#  {'id': '이용원', 'occupation': '수석전문위원'},
#  {'id': '이자스민', 'occupation': '위원'},
#  {'id': '김규현', 'occupation': '외교부1차관'},
#  {'id': '남인순', 'occupation': '위원'},
#  {'id': '김규현', 'occupation': '외교통상부제1차관'},
#  {'id': '인재근', 'occupation': '위원'},
#  {'id': '차인순', 'occupation': '입법심의관'},
#  {'id': '심보균', 'occupation': '여성가족부기획조정실장'},
#  {'id': '김재련', 'occupation': '여성가족부권익증진국장'}]
# ' 제320회국회(정기회) 교육문화체육관광위원회회의록(청원심사소위원회) 제1호'
# '20131118'
# [{'id': '이학재', 'occupation': '소위원장'},
#  {'id': '김상희', 'occupation': '위원'},
#  {'id': '현영희', 'occupation': '위원'},
#  {'id': '임진대', 'occupation': '수석전문위원'},
#  {'id': '박용수', 'occupation': '전문위원'},
#  {'id': '나승일', 'occupation': '교육부차관'},
#  {'id': '정병걸', 'occupation': '교육부지방교육지원국장'},
#  {'id': '김양수', 'occupation': '한국특수교육총연합회장'},
#  {'id': '우원식', 'occupation': '위원'},
#  {'id': '심정희', 'occupation': '입법조사관'},
#  {'id': '성삼제', 'occupation': '교육부기획조정실장'},
#  {'id': '이승재', 'occupation': '입법심의관'},
#  {'id': '박영대', 'occupation': '문화재청장직무대행'},
#  {'id': '박백범', 'occupation': '교육부대학지원실장'},
#  {'id': '황홍규', 'occupation': '교육부학생복지안전관'},
#  {'id': '박춘란', 'occupation': '교육부대학정책관'},
#  {'id': '서유미', 'occupation': '교육부학술장학지원관'},
#  {'id': '박영근', 'occupation': '문화재청문화재활용국장'}]
# ' 제320회국회(정기회) 국토교통위원회회의록(교통법안심사소위원회) 제1호'
# '20131008'
# [{'id': '박상은', 'occupation': '소위원장'},
#  {'id': '김요환', 'occupation': '전문위원'},
#  {'id': '여형구', 'occupation': '국토교통부제2차관'},
#  {'id': '임내현', 'occupation': '위원'},
#  {'id': '민홍철', 'occupation': '위원'},
#  {'id': '윤후덕', 'occupation': '위원'},
#  {'id': '이장우', 'occupation': '위원'},
#  {'id': '조현룡', 'occupation': '위원'},
#  {'id': '박종흠', 'occupation': '국토교통부교통물류실장'},
#  {'id': '김경욱', 'occupation': '국토교통부철도국장'},
#  {'id': '李憲昇', 'occupation': '위원'},
#  {'id': '이철우', 'occupation': '위원'},
#  {'id': '최정호', 'occupation': '국토교통부항공정책실장'},
#  {'id': '권병윤', 'occupation': '국토교통부도로국장'}]
# ' 제320회국회(정기회) 국토교통위원회회의록(교통법안심사소위원회) 제5호'
# '20131209'
# [{'id': '박상은', 'occupation': '소위원장'},
#  {'id': '조현룡', 'occupation': '위원'},
#  {'id': '김요환', 'occupation': '전문위원'},
#  {'id': '박기풍', 'occupation': '국토교통부제1차관'},
#  {'id': '이장우', 'occupation': '위원'},
#  {'id': '민홍철', 'occupation': '위원'},
#  {'id': '임내현', 'occupation': '위원'},
#  {'id': '李憲昇', 'occupation': '위원'},
#  {'id': '윤후덕', 'occupation': '위원'},
#  {'id': '박종흠', 'occupation': '국토교통부교통물류실장'},
#  {'id': '맹성규', 'occupation': '국토교통부종합교통정책관'},
#  {'id': '이철우', 'occupation': '위원'},
#  {'id': '문병호', 'occupation': '위원'}]
# ' 제320회국회(정기회) 국토교통위원회회의록(예산결산기금심사소위원회) 제3호'
# '20131205'
# [{'id': '강석호', 'occupation': '소위원장'},
#  {'id': '신장용', 'occupation': '위원'},
#  {'id': '허태수', 'occupation': '수석전문위원'},
#  {'id': '여형구', 'occupation': '국토교통부제2차관'},
#  {'id': '박수현', 'occupation': '위원'},
#  {'id': '정병윤', 'occupation': '국토교통부국토도시실장'},
#  {'id': '이이재', 'occupation': '위원'},
#  {'id': '변재일', 'occupation': '위원'},
#  {'id': '박상우', 'occupation': '국토교통부기획조정실장'},
#  {'id': '한창섭', 'occupation': '국토교통부용산공원추진기획단장'},
#  {'id': '손병석', 'occupation': '국토교통부수자원정책국장'},
#  {'id': '김경욱', 'occupation': '국토교통부철도국장'},
#  {'id': '이종진', 'occupation': '위원'},
#  {'id': '홍형표', 'occupation': '행정중심복합도시건설청차장'},
#  {'id': '도태호', 'occupation': '국토교통부주택토지실장'},
#  {'id': '김요환', 'occupation': '전문위원'},
#  {'id': '김태흠', 'occupation': '위원'},
#  {'id': '권병윤', 'occupation': '국토교통부도로국장'},
#  {'id': '전병국', 'occupation': '새만금개발청차장'},
#  {'id': '김무성', 'occupation': '위원'},
#  {'id': '박종흠', 'occupation': '국토교통부교통물류실장'},
#  {'id': '최정호', 'occupation': '국토교통부항공정책실장'}]
# ' 제320회국회(정기회) 국토교통위원회회의록(청원심사소위원회) 제1호'
# '20131008'
# [{'id': '문병호', 'occupation': '소위원장'},
#  {'id': '심재철', 'occupation': '위원'},
#  {'id': '변재일', 'occupation': '위원'},
#  {'id': '장태성', 'occupation': '입법조사관'},
#  {'id': '박기풍', 'occupation': '국토교통부제1차관'},
#  {'id': '허태수', 'occupation': '수석전문위원'},
#  {'id': '한병홍', 'occupation': '한국토지주택공사세종혁신도시처장'},
#  {'id': '정갑윤', 'occupation': '의원'},
#  {'id': '이상구', 'occupation': '서동고가차도저지·교통소음해결·동천제방도로개설을위한주민대책위원장'},
#  {'id': '함진규', 'occupation': '위원'},
#  {'id': '김요환', 'occupation': '전문위원'},
#  {'id': '윤후덕', 'occupation': '의원'},
#  {'id': '안효대', 'occupation': '위원'},
#  {'id': '박기풍', 'occupation': '국토해양부제1차관'},
#  {'id': '柳一鎬', 'occupation': '의원'},
#  {'id': '도태호', 'occupation': '국토교통부주택토지실장'},
#  {'id': '이상후', 'occupation': '한국토지주택공사주거복지본부장'},
#  {'id': '이윤석', 'occupation': '위원'},
#  {'id': '정우택', 'occupation': '위원'},
#  {'id': '손병석', 'occupation': '국토교통부수자원정책국장'},
#  {'id': '박종흠', 'occupation': '국토교통부교통물류실장'}]
# ' 제320회국회(정기회) 안전행정위원회회의록(법안심사소위원회) 제4호'
# '20131210'
# [{'id': '황영철', 'occupation': '소위원장'},
#  {'id': '임재주', 'occupation': '전문위원'},
#  {'id': '김용희', 'occupation': '중앙선거관리위원회사무차장'},
#  {'id': '윤재옥', 'occupation': '위원'},
#  {'id': '백재현', 'occupation': '위원'},
#  {'id': '유대운', 'occupation': '위원'},
#  {'id': '진선미', 'occupation': '위원'},
#  {'id': '윤석근', 'occupation': '중앙선거관리위원회선거정책실장'},
#  {'id': '박영수', 'occupation': '중앙선거관리위원회법제국장'},
#  {'id': '金永柱', 'occupation': '위원'},
#  {'id': '김민기', 'occupation': '위원'},
#  {'id': '이찬열', 'occupation': '위원'},
#  {'id': '손충덕', 'occupation': '수석전문위원'}]
# ' 제320회국회(정기회) 기획재정위원회회의록(예산결산기금심사소위원회) 제3호'
# '20131210'
# [{'id': '설훈', 'occupation': '소위원장'},
#  {'id': '이낙연', 'occupation': '위원'},
#  {'id': '김승기', 'occupation': '전문위원'},
#  {'id': '이전환', 'occupation': '국세청차장'},
#  {'id': '류성걸', 'occupation': '위원'},
#  {'id': '이한성', 'occupation': '위원'},
#  {'id': '홍종학', 'occupation': '위원'},
#  {'id': '나동균', 'occupation': '국세청기획조정관'},
#  {'id': '김영기', 'occupation': '국세청조사국장'},
#  {'id': '정철우', 'occupation': '국세청기획재정담당관'},
#  {'id': '류환민', 'occupation': '수석전문위원'},
#  {'id': '추경호', 'occupation': '기획재정부제1차관'},
#  {'id': '최원목', 'occupation': '기획재정부기획조정실장'}]
# ' 제320회국회(정기회) 기획재정위원회회의록(조세소위원회) 제2호'
# '20131205'
# [{'id': '나성린', 'occupation': '소위원장'},
#  {'id': '이한성', 'occupation': '위원'},
#  {'id': '이용섭', 'occupation': '위원'},
#  {'id': '김승기', 'occupation': '전문위원'},
#  {'id': '윤호중', 'occupation': '위원'},
#  {'id': '류성걸', 'occupation': '위원'},
#  {'id': '박원석', 'occupation': '위원'},
#  {'id': '안종범', 'occupation': '위원'},
#  {'id': '홍종학', 'occupation': '위원'},
#  {'id': '김낙회', 'occupation': '기획재정부세제실장'},
#  {'id': '이만우', 'occupation': '위원'},
#  {'id': '이석준', 'occupation': '기획재정부제2차관'},
#  {'id': '정성호', 'occupation': '위원'},
#  {'id': '조정식', 'occupation': '위원'}]
# ' 제321회국회(임시회) 교육문화체육관광위원회회의록(법안심사소위원회) 제1호'
# '20131219'
# [{'id': '김희정', 'occupation': '소위원장'},
#  {'id': '도종환', 'occupation': '위원'},
#  {'id': '임진대', 'occupation': '수석전문위원'},
#  {'id': '유기홍', 'occupation': '위원'},
#  {'id': '유은혜', 'occupation': '위원'},
#  {'id': '박백범', 'occupation': '교육부대학지원실장'},
#  {'id': '성삼제', 'occupation': '교육부기획조정실장'},
#  {'id': '박융수', 'occupation': '교육부평생직업교육국장'},
#  {'id': '강은희', 'occupation': '위원'},
#  {'id': '김태년', 'occupation': '위원'},
#  {'id': '박인숙', 'occupation': '위원'},
#  {'id': '이에리사', 'occupation': '위원'},
#  {'id': '심민철', 'occupation': '교육부재외동포교육담당관'},
#  {'id': '김장실', 'occupation': '위원'},
#  {'id': '박용수', 'occupation': '전문위원'},
#  {'id': '나승일', 'occupation': '교육부차관'},
#  {'id': '심은석', 'occupation': '교육부교육정책실장'},
#  {'id': '정종철', 'occupation': '교육부정책기획관'},
#  {'id': '강영순', 'occupation': '교육부국제협력관'},
#  {'id': '김영윤', 'occupation': '교육부학교정책관'},
#  {'id': '김성기', 'occupation': '교육부창의인재정책관'},
#  {'id': '황홍규', 'occupation': '교육부학생복지안전관'},
#  {'id': '박춘란', 'occupation': '교육부대학정책관'},
#  {'id': '한석수', 'occupation': '교육부대학지원관'},
#  {'id': '서유미', 'occupation': '교육부학술장학지원관'},
#  {'id': '정병걸', 'occupation': '교육부지방교육지원국장'}]
# ' 제321회국회(임시회) 국방위원회회의록(법률안심사소위원회) 제2호'
# '20131230'
# [{'id': '안규백', 'occupation': '소위원장'},
#  {'id': '권기율', 'occupation': '수석전문위원'},
#  {'id': '백군기', 'occupation': '위원'},
#  {'id': '송영근', 'occupation': '위원'},
#  {'id': '백승주', 'occupation': '국방부차관'},
#  {'id': '김종태', 'occupation': '위원'},
#  {'id': '김재윤', 'occupation': '위원'},
#  {'id': '박찬웅', 'occupation': '국방부인사기획관'},
#  {'id': '유기준', 'occupation': '위원'},
#  {'id': '한기호', 'occupation': '위원'},
#  {'id': '강병주', 'occupation': '국방부전력정책관'},
#  {'id': '손인춘', 'occupation': '위원'},
#  {'id': '구병회', 'occupation': '전문위원'},
#  {'id': '김철수', 'occupation': '방위사업청차장'},
#  {'id': '김종출', 'occupation': '방위사업청기획조정관'}]
# ' 제321회국회(임시회) 국토교통위원회회의록(국토법안심사소위원회) 제1호'
# '20131226'
# [{'id': '박기춘', 'occupation': '소위원장'},
#  {'id': '허태수', 'occupation': '수석전문위원'},
#  {'id': '박기풍', 'occupation': '국토교통부제1차관'},
#  {'id': '이미경', 'occupation': '위원'},
#  {'id': '이노근', 'occupation': '위원'},
#  {'id': '오병윤', 'occupation': '위원'},
#  {'id': '김태원', 'occupation': '위원'},
#  {'id': '도태호', 'occupation': '국토교통부주택토지실장'},
#  {'id': '김관영', 'occupation': '위원'},
#  {'id': '김재정', 'occupation': '국토교통부주택정책관'},
#  {'id': '함진규', 'occupation': '위원'},
#  {'id': '이상일', 'occupation': '국토교통부부동산산업과장'},
#  {'id': '안효대', 'occupation': '위원'}]
# ' 제321회국회(임시회) 법제사법위원회회의록(예산결산심사소위원회) 제2호'
# '20131212'
# [{'id': '권성동', 'occupation': '소위원장'},
#  {'id': '임중호', 'occupation': '수석전문위원'},
#  {'id': '서영교', 'occupation': '위원'},
#  {'id': '이춘석', 'occupation': '위원'},
#  {'id': '이복실', 'occupation': '여성가족부차관'},
#  {'id': '국민수', 'occupation': '법무부차관'},
#  {'id': '노철래', 'occupation': '위원'},
#  {'id': '문광섭', 'occupation': '전문위원'},
#  {'id': '김영호', 'occupation': '감사원사무총장'},
#  {'id': '왕정홍', 'occupation': '감사원기획조정실장'},
#  {'id': '박범계', 'occupation': '위원'},
#  {'id': '권성동', 'occupation': '위원'},
#  {'id': '서기호', 'occupation': '위원'},
#  {'id': '정갑윤', 'occupation': '위원'},
#  {'id': '이상용', 'occupation': '전문위원'},
#  {'id': '정재룡', 'occupation': '전문위원'},
#  {'id': '봉욱', 'occupation': '법무부기획조정실장'}]
# ' 제321회국회(임시회) 보건복지위원회회의록(예산결산심사소위원회) 제2호'
# '20131212'
# [{'id': '이목희', 'occupation': '소위원장'},
#  {'id': '김대현', 'occupation': '수석전문위원'},
#  {'id': '이준균', 'occupation': '보건복지부보육정책관'},
#  {'id': '김성주', 'occupation': '위원'},
#  {'id': '이영찬', 'occupation': '보건복지부차관'},
#  {'id': '방석배', 'occupation': '보건복지부보육기반과장'},
#  {'id': '김명연', 'occupation': '위원'},
#  {'id': '金熙國', 'occupation': '위원'},
#  {'id': '전만복', 'occupation': '보건복지부기획조정실장'},
#  {'id': '김정록', 'occupation': '위원'},
#  {'id': '민현주', 'occupation': '위원'},
#  {'id': '이상진', 'occupation': '보건복지부보육사업기획과장'},
#  {'id': '김미희', 'occupation': '위원'},
#  {'id': '문정림', 'occupation': '위원'},
#  {'id': '양성일', 'occupation': '보건복지부연금정책국장'},
#  {'id': '정재인', 'occupation': '전문위원'},
#  {'id': '임종규', 'occupation': '보건복지부건강정책국장'},
#  {'id': '박인석', 'occupation': '보건복지부보건산업정책국장'}]
# ' 제321회국회(임시회) 여성가족위원회회의록(법안심사소위원회) 제2호'
# '20131216'
# [{'id': '김현숙', 'occupation': '소위원장'},
#  {'id': '이용원', 'occupation': '수석전문위원'},
#  {'id': '남인순', 'occupation': '위원'},
#  {'id': '이복실', 'occupation': '여성가족부차관'},
#  {'id': '박완주', 'occupation': '위원'},
#  {'id': '이자스민', 'occupation': '위원'},
#  {'id': '김형수', 'occupation': '기획재정부문화예산과장'},
#  {'id': '백재현', 'occupation': '위원'},
#  {'id': '신의진', 'occupation': '위원'},
#  {'id': '차인순', 'occupation': '입법심의관'},
#  {'id': '김재련', 'occupation': '여성가족부권익증진국장'}]
# ' 제322회국회(임시회) 국방위원회회의록(법률안심사소위원회) 제3호'
# '20140226'
# [{'id': '안규백', 'occupation': '소위원장'},
#  {'id': '성석호', 'occupation': '수석전문위원'},
#  {'id': '한기호', 'occupation': '위원'},
#  {'id': '송영근', 'occupation': '위원'},
#  {'id': '김재윤', 'occupation': '위원'},
#  {'id': '유기준', 'occupation': '위원'},
#  {'id': '백승주', 'occupation': '국방부차관'},
#  {'id': '백군기', 'occupation': '위원'},
#  {'id': '김철수', 'occupation': '방위사업청차장'},
#  {'id': '강병주', 'occupation': '국방부전력정책관'},
#  {'id': '김종태', 'occupation': '위원'},
#  {'id': '정근배', 'occupation': '국방부보건복지관'},
#  {'id': '권기원', 'occupation': '전문위원'}]
# ' 제322회국회(임시회) 법제사법위원회회의록(법안심사제1소위원회) 제2호'
# '20140225'
# [{'id': '임중호', 'occupation': '수석전문위원'},
#  {'id': '김현웅', 'occupation': '법무부차관'},
#  {'id': '이용욱', 'occupation': '해양경찰청정보수사국장'},
#  {'id': '권순일', 'occupation': '법원행정처차장'},
#  {'id': '정재룡', 'occupation': '전문위원'},
#  {'id': '서영교', 'occupation': '위원'},
#  {'id': '이춘석', 'occupation': '위원'},
#  {'id': '김진태', 'occupation': '위원'},
#  {'id': '전해철', 'occupation': '위원'},
#  {'id': '김회선', 'occupation': '위원'},
#  {'id': '정인창', 'occupation': '법무부법무실장'},
#  {'id': '박범계', 'occupation': '위원'},
#  {'id': '이준식', 'occupation': '법무부상사법무과장'},
#  {'id': '서기호', 'occupation': '위원'},
#  {'id': '김도읍', 'occupation': '위원'},
#  {'id': '김학용', 'occupation': '위원'},
#  {'id': '권성동', 'occupation': '위원'},
#  {'id': '박영선', 'occupation': '의원'},
#  {'id': '강남일', 'occupation': '전문위원'}]
# ' 제322회국회(임시회) 여성가족위원회회의록(일본군위안부문제대책소위원회) 제1호'
# '20140207'
# [{'id': '길정우', 'occupation': '소위원장'},
#  {'id': '김현숙', 'occupation': '위원'},
#  {'id': '이복실', 'occupation': '여성가족부차관'},
#  {'id': '인재근', 'occupation': '위원'},
#  {'id': '이자스민', 'occupation': '위원'},
#  {'id': '남인순', 'occupation': '위원'},
#  {'id': '이용원', 'occupation': '수석전문위원'},
#  {'id': '김재련', 'occupation': '여성가족부권익증진국장'},
#  {'id': '유승희', 'occupation': '위원'},
#  {'id': '차인순', 'occupation': '입법심의관'}]
# ' 제322회국회(임시회) 외교통일위원회회의록(법안심사소위원회) 제2호'
# '20140220'
# [{'id': '정문헌', 'occupation': '소위원장'},
#  {'id': '심재권', 'occupation': '위원'},
#  {'id': '황진하', 'occupation': '위원'},
#  {'id': '이용준', 'occupation': '전문위원'},
#  {'id': '심윤조', 'occupation': '위원'},
#  {'id': '김남식', 'occupation': '통일부차관'},
#  {'id': '홍익표', 'occupation': '위원'},
#  {'id': '이종후', 'occupation': '수석전문위원'},
#  {'id': '김기웅', 'occupation': '통일부통일정책실장직무대리'},
#  {'id': '이수영', 'occupation': '통일부교류협력국장'}]
# ' 제322회국회(임시회) 기획재정위원회회의록(경제재정소위원회) 제1호'
# '20140217'
# [{'id': '김현미', 'occupation': '소위원장'},
#  {'id': '류환민', 'occupation': '수석전문위원'},
#  {'id': '추경호', 'occupation': '기획재정부제1차관'},
#  {'id': '안종범', 'occupation': '위원'},
#  {'id': '장설희', 'occupation': '입법조사관'},
#  {'id': '김상규', 'occupation': '기획재정부재정업무관리관'},
#  {'id': '박명재', 'occupation': '위원'},
#  {'id': '곽범국', 'occupation': '기획재정부국고국장'},
#  {'id': '李宰榮', 'occupation': '위원'},
#  {'id': '이인영', 'occupation': '위원'},
#  {'id': '구병성', 'occupation': '입법조사관'},
#  {'id': '설훈', 'occupation': '위원'},
#  {'id': '이태성', 'occupation': '기획재정부재정관리국장'},
#  {'id': '최민영', 'occupation': '입법조사관'},
#  {'id': '최재성', 'occupation': '위원'}]
# ' 제323회국회(임시회) 국방위원회회의록(법률안심사소위원회) 제2호'
# '20140418'
# [{'id': '안규백', 'occupation': '소위원장'},
#  {'id': '성석호', 'occupation': '수석전문위원'},
#  {'id': '백승주', 'occupation': '국방부차관'},
#  {'id': '한기호', 'occupation': '위원'},
#  {'id': '송영근', 'occupation': '위원'},
#  {'id': '김종태', 'occupation': '위원'},
#  {'id': '임천영', 'occupation': '국방부법무관리관'},
#  {'id': '김재윤', 'occupation': '위원'},
#  {'id': '백군기', 'occupation': '위원'},
#  {'id': '박찬웅', 'occupation': '국방부인사기획관'},
#  {'id': '지경식', 'occupation': '국방부복지정책과장'},
#  {'id': '권기원', 'occupation': '전문위원'},
#  {'id': '안병태', 'occupation': '국방부동원기획관'},
#  {'id': '유기준', 'occupation': '위원'},
#  {'id': '정근배', 'occupation': '국방부보건복지관'},
#  {'id': '이상욱', 'occupation': '국방부군수관리관'},
#  {'id': '정대현', 'occupation': '국방부국방교육정책관'},
#  {'id': '강병주', 'occupation': '국방부전력정책관'},
#  {'id': '황희종', 'occupation': '국방부군사시설기획관'},
#  {'id': '노병균', 'occupation': '국방부정보기획부장'},
#  {'id': '조상호', 'occupation': '국방부군구조개혁추진관'}]
# ' 제323회국회(임시회) 국토교통위원회회의록(철도산업발전소위원회) 제3호'
# '20140416'
# [{'id': '강석호', 'occupation': '소위원장'},
#  {'id': '김요환', 'occupation': '전문위원'},
#  {'id': '민홍철', 'occupation': '위원'},
#  {'id': '윤후덕', 'occupation': '위원'},
#  {'id': '오병윤', 'occupation': '위원'},
#  {'id': '최연혜', 'occupation': '한국철도공사사장'},
#  {'id': '박상은', 'occupation': '위원'},
#  {'id': '이이재', 'occupation': '위원'},
#  {'id': '여형구', 'occupation': '국토교통부제2차관'},
#  {'id': '최인혜', 'occupation': '한국철도공사사장'},
#  {'id': '여형구', 'occupation': '국토교통부제2차고나'},
#  {'id': '안효대', 'occupation': '위원'},
#  {'id': '박상은', 'occupation': '소위원장'},
#  {'id': '이윤석', 'occupation': '위원'}]
# ' 제323회국회(임시회) 국토교통위원회회의록(청원심사소위원회) 제1호'
# '20140411'
# [{'id': '문병호', 'occupation': '소위원장'},
#  {'id': '허태수', 'occupation': '수석전문위원'},
#  {'id': '여형구', 'occupation': '국토교통부제2차관'},
#  {'id': '정영진', 'occupation': '입법조사관'},
#  {'id': '김상일', 'occupation': '청원인'},
#  {'id': '심재철', 'occupation': '위원'},
#  {'id': '김중회', 'occupation': '㈜대우건설주택CM기술팀장'},
#  {'id': '안효대', 'occupation': '위원'},
#  {'id': '김재정', 'occupation': '국토교통부주택정책관'},
#  {'id': '김요환', 'occupation': '전문위원'},
#  {'id': '정연철', 'occupation': '청원인'},
#  {'id': '장태성', 'occupation': '입법조사관'},
#  {'id': '장영수', 'occupation': '국토교통부공항항행정책관'},
#  {'id': '변재일', 'occupation': '위원'},
#  {'id': '정우택', 'occupation': '위원'}]
# ' 제323회국회(임시회) 보건복지위원회회의록(법안심사소위원회) 제3호'
# '20140416'
# [{'id': '柳在仲', 'occupation': '소위원장'},
#  {'id': '정기혜', 'occupation': '진술인'},
#  {'id': '정명섭', 'occupation': '진술인'},
#  {'id': '정병호', 'occupation': '진술인'},
#  {'id': '조윤미', 'occupation': '진술인'},
#  {'id': '이언주', 'occupation': '위원'},
#  {'id': '강봉한', 'occupation': '식품의약품안전처식품안전정책국장'},
#  {'id': '김현숙', 'occupation': '위원'},
#  {'id': '신의진', 'occupation': '위원'},
#  {'id': '전종민', 'occupation': '식품의약품안전처통상협력팀장'},
#  {'id': '최동익', 'occupation': '위원'},
#  {'id': '류지영', 'occupation': '위원'},
#  {'id': '남인순', 'occupation': '위원'},
#  {'id': '김용익', 'occupation': '위원'},
#  {'id': '김대현', 'occupation': '수석전문위원'},
#  {'id': '정재인', 'occupation': '전문위원'},
#  {'id': '장병원', 'occupation': '식품의약품안전처차장'},
#  {'id': '조기원', 'occupation': '식품의약품안전처기획조정관'},
#  {'id': '최동미', 'occupation': '식품의약품안전처식품영양안전국장'}]
# ' 제323회국회(임시회) 환경노동위원회회의록(노사정사회적논의촉진을위한소위원회) 제1호'
# '20140407'
# [{'id': '신계륜', 'occupation': '소위원장'},
#  {'id': '김성태', 'occupation': '위원'},
#  {'id': '홍영표', 'occupation': '위원'},
#  {'id': '방하남', 'occupation': '고용노동부장관'},
#  {'id': '이종훈', 'occupation': '위원'},
#  {'id': '김동만', 'occupation': '한국노동조합총연맹위원장'},
#  {'id': '김영배', 'occupation': '한국경영자총협회장직무대행'},
#  {'id': '김기문', 'occupation': '중소기업중앙회장'},
#  {'id': '박용만', 'occupation': '대한상공회의소회장'},
#  {'id': '한공식', 'occupation': '수석전문위원'},
#  {'id': '김양건', 'occupation': '전문위원'}]
# ' 제324회국회(임시회) 국방위원회회의록(법률안심사소위원회) 제1호'
# '20140421'
# [{'id': '안규백', 'occupation': '소위원장'},
#  {'id': '김학배', 'occupation': '입법조사관'},
#  {'id': '성석호', 'occupation': '수석전문위원'},
#  {'id': '송영근', 'occupation': '위원'},
#  {'id': '백군기', 'occupation': '위원'},
#  {'id': '김종태', 'occupation': '위원'},
#  {'id': '백승주', 'occupation': '국방부차관'},
#  {'id': '정대현', 'occupation': '국방부국방교육정책관'},
#  {'id': '권기원', 'occupation': '전문위원'},
#  {'id': '정희갑', 'occupation': '기획재정부국방예산과장'},
#  {'id': '정환식', 'occupation': '병무청차장'},
#  {'id': '유기준', 'occupation': '위원'},
#  {'id': '이성수', 'occupation': '병무청병역자원국장'},
#  {'id': '정병익', 'occupation': '교육부학술진흥과장'},
#  {'id': '박찬웅', 'occupation': '국방부인사기획관'},
#  {'id': '강병주', 'occupation': '국방부전력정책관'},
#  {'id': '김영산', 'occupation': '방위사업청장비물자계약부장'},
#  {'id': '김철수', 'occupation': '방위사업청차장'},
#  {'id': '김인호', 'occupation': '국방부기획관리관'},
#  {'id': '정근배', 'occupation': '국방부보건복지관'},
#  {'id': '임천영', 'occupation': '국방부법무관리관'},
#  {'id': '이상욱', 'occupation': '국방부군수관리관'},
#  {'id': '안병태', 'occupation': '국방부동원기획관'},
#  {'id': '황희종', 'occupation': '국방부군사시설기획관'},
#  {'id': '노병균', 'occupation': '국방부정보본부정보기획부장'},
#  {'id': '조상호', 'occupation': '국방부군구조개혁추진관'},
#  {'id': '김태화', 'occupation': '병무청입영동원국장'},
#  {'id': '김노운', 'occupation': '병무청사회복무국장'},
#  {'id': '김종출', 'occupation': '방위사업청기획조정관'},
#  {'id': '문기정', 'occupation': '방위사업청획득기획국장'}]
# ' 제324회국회(임시회) 법제사법위원회회의록(법안심사제2소위원회) 제1호'
# '20140422'
# [{'id': '이춘석', 'occupation': '소위원장'},
#  {'id': '정재룡', 'occupation': '전문위원'},
#  {'id': '김재홍', 'occupation': '산업통상자원부제1차관'},
#  {'id': '서영교', 'occupation': '위원'},
#  {'id': '한진현', 'occupation': '산업통상자원부제2차관'},
#  {'id': '강남일', 'occupation': '전문위원'},
#  {'id': '정현옥', 'occupation': '고용노동부차관'},
#  {'id': '권성동', 'occupation': '위원'},
#  {'id': '김진태', 'occupation': '위원'},
#  {'id': '전해철', 'occupation': '위원'},
#  {'id': '노철래', 'occupation': '위원'},
#  {'id': '신경민', 'occupation': '위원'},
#  {'id': '김회선', 'occupation': '위원'},
#  {'id': '김학용', 'occupation': '위원'},
#  {'id': '박종길', 'occupation': '고용노동부산재예방보상정책국장'},
#  {'id': '임중호', 'occupation': '수석전문위원'},
#  {'id': '추경호', 'occupation': '기획재정부제1차관'},
#  {'id': '정규남', 'occupation': '통계청차장'},
#  {'id': '곽정태', 'occupation': '법원행정처가족관계등록과장'},
#  {'id': '하상구', 'occupation': '경찰청수사국수사기획과장'},
#  {'id': '여형구', 'occupation': '국토교통부제2차관'},
#  {'id': '김용희', 'occupation': '중앙선거관리위원회사무차장'},
#  {'id': '진선미', 'occupation': '의원'},
#  {'id': '이인선', 'occupation': '경찰청차장'},
#  {'id': '심태규', 'occupation': '전문위원'}]
# ' 제324회국회(임시회) 기획재정위원회회의록(조세개혁소위원회) 제1호'
# '20140422'
# [{'id': '조정식', 'occupation': '소위원장'},
#  {'id': '박용주', 'occupation': '진술인'},
#  {'id': '홍범교', 'occupation': '진술인'},
#  {'id': '김낙회', 'occupation': '기획재정부세제실장'},
#  {'id': '나성린', 'occupation': '위원'},
#  {'id': '안종범', 'occupation': '위원'},
#  {'id': '이현철', 'occupation': '금융위원회자본시장국장'},
#  {'id': '金光琳', 'occupation': '위원'},
#  {'id': '이인영', 'occupation': '위원'},
#  {'id': '류성걸', 'occupation': '위원'},
#  {'id': '박원석', 'occupation': '위원'},
#  {'id': '홍종학', 'occupation': '위원'},
#  {'id': '김승기', 'occupation': '전문위원'}]
# ' 제324회국회(임시회) 환경노동위원회회의록(법안심사소위원회) 제1호'
# '20140421'
# [{'id': '김성태', 'occupation': '소위원장'},
#  {'id': '심상정', 'occupation': '위원'},
#  {'id': '이완영', 'occupation': '위원'},
#  {'id': '이종훈', 'occupation': '위원'},
#  {'id': '홍영표', 'occupation': '위원'},
#  {'id': '최봉홍', 'occupation': '위원'},
#  {'id': '김양건', 'occupation': '전문위원'},
#  {'id': '정현옥', 'occupation': '고용노동부차관'},
#  {'id': '은수미', 'occupation': '위원'},
#  {'id': '한정애', 'occupation': '위원'},
#  {'id': '나영돈', 'occupation': '고용노동부직업능력정책관'},
#  {'id': '이경선', 'occupation': '비서관'},
#  {'id': '한공식', 'occupation': '수석전문위원'},
#  {'id': '권영순', 'occupation': '고용노동부노동정책실장'},
#  {'id': '김종열', 'occupation': '고용노동부정책기획관'},
#  {'id': '정형우', 'occupation': '고용노동부노동시장정책관'},
#  {'id': '이수영', 'occupation': '고용노동부고령사회인력심의관'},
#  {'id': '임무송', 'occupation': '고용노동부근로개선정책관'},
#  {'id': '박화진', 'occupation': '고용노동부노사협력정책관'}]
# ' 제326회국회(임시회) 국방위원회회의록(법률안심사소위원회) 제1호'
# '20140717'
# [{'id': '윤후덕', 'occupation': '소위원장'},
#  {'id': '성석호', 'occupation': '수석전문위원'},
#  {'id': '한기호', 'occupation': '위원'},
#  {'id': '김광우', 'occupation': '국방부기획조정실장'},
#  {'id': '손인춘', 'occupation': '위원'},
#  {'id': '정근배', 'occupation': '국방부보건복지관'},
#  {'id': '김광진', 'occupation': '위원'},
#  {'id': '황희종', 'occupation': '국방부군사시설기획관'},
#  {'id': '김철수', 'occupation': '방위사업청차장'},
#  {'id': '백군기', 'occupation': '위원'},
#  {'id': '이재익', 'occupation': '방위사업청계약관리본부장'},
#  {'id': '金世淵', 'occupation': '위원'},
#  {'id': '권기원', 'occupation': '전문위원'},
#  {'id': '박찬웅', 'occupation': '국방부인사기획관'},
#  {'id': '정환식', 'occupation': '병무청차장'},
#  {'id': '김인호', 'occupation': '국방부기획관리관'},
#  {'id': '장갑수', 'occupation': '병무청기획조정관'},
#  {'id': '김형택', 'occupation': '방위사업청원가회계검증단장'},
#  {'id': '김원식', 'occupation': '방위사업청계획운영부장'}]
# ' 제326회국회(임시회) 법제사법위원회회의록(법안심사제1소위원회) 제2호'
# '20140711'
# [{'id': '홍일표', 'occupation': '소위원장'},
#  {'id': '임중호', 'occupation': '수석전문위원'},
#  {'id': '김현웅', 'occupation': '법무부차관'},
#  {'id': '권순일', 'occupation': '법원행정처차장'},
#  {'id': '임내현', 'occupation': '위원'},
#  {'id': '전해철', 'occupation': '위원'},
#  {'id': '서영교', 'occupation': '위원'},
#  {'id': '김도읍', 'occupation': '위원'},
#  {'id': '정재룡', 'occupation': '전문위원'},
#  {'id': '서기호', 'occupation': '위원'},
#  {'id': '한무근', 'occupation': '법무부출입국·외국인정책본부장'},
#  {'id': '강남일', 'occupation': '전문위원'},
#  {'id': '심태규', 'occupation': '전문위원'},
#  {'id': '이준식', 'occupation': '법무부상사법무과장'},
#  {'id': '임천영', 'occupation': '국방부법무관리관'},
#  {'id': '김진태', 'occupation': '위원'}]
# ' 제326회국회(임시회) 법제사법위원회회의록(법안심사제2소위원회) 제1호'
# '20140715'
# [{'id': '전해철', 'occupation': '소위원장'},
#  {'id': '정재근', 'occupation': '안전행정부지방행정실장'},
#  {'id': '조성완', 'occupation': '소방방재청차장'},
#  {'id': '임중호', 'occupation': '수석전문위원'},
#  {'id': '서영교', 'occupation': '위원'},
#  {'id': '박민식', 'occupation': '위원'},
#  {'id': '이정구', 'occupation': '안전행정부지방공무원과장'},
#  {'id': '홍일표', 'occupation': '위원'},
#  {'id': '이인선', 'occupation': '경찰청차장'},
#  {'id': '이한성', 'occupation': '위원'},
#  {'id': '박춘섭', 'occupation': '기획재정부경제예산심의관'},
#  {'id': '노철래', 'occupation': '위원'},
#  {'id': '정재룡', 'occupation': '전문위원'},
#  {'id': '백승주', 'occupation': '국방부차관'},
#  {'id': '임천영', 'occupation': '국방부법무관리관'},
#  {'id': '윤종록', 'occupation': '미래창조과학부제2차관'},
#  {'id': '허원제', 'occupation': '방송통신위원회부위원장'},
#  {'id': '심태규', 'occupation': '전문위원'},
#  {'id': '이춘석', 'occupation': '위원'},
#  {'id': '류제명', 'occupation': '미래창조과학부통신이용제도과장'},
#  {'id': '백장운', 'occupation': '입법조사관'},
#  {'id': '강남일', 'occupation': '전문위원'},
#  {'id': '박경국', 'occupation': '안전행정부제1차관'}]
# ' 제326회국회(임시회) 기획재정위원회회의록(2013회계연도결산심사소위원회) 제1호'
# '20140714'
# [{'id': '박명재', 'occupation': '소위원장'},
#  {'id': '홍종학', 'occupation': '위원'},
#  {'id': '박덕흠', 'occupation': '위원'},
#  {'id': '류환민', 'occupation': '수석전문위원'},
#  {'id': '추경호', 'occupation': '기획재정부제1차관'},
#  {'id': '류성걸', 'occupation': '위원'},
#  {'id': '김승기', 'occupation': '전문위원'},
#  {'id': '최재성', 'occupation': '위원'},
#  {'id': '최원목', 'occupation': '기획재정부기획조정실장'}]
# ' 제327회국회(임시회) 보건복지위원회회의록(예산결산심사소위원회) 제2호'
# '20140724'
# [{'id': '김성주', 'occupation': '소위원장'},
#  {'id': '김대현', 'occupation': '수석전문위원'},
#  {'id': '윤현덕', 'occupation': '보건복지부장애인정책국장'},
#  {'id': '김정록', 'occupation': '위원'},
#  {'id': '이종진', 'occupation': '위원'},
#  {'id': '김명연', 'occupation': '위원'},
#  {'id': '김헌주', 'occupation': '보건복지부인구아동정책관'},
#  {'id': '이영찬', 'occupation': '보건복지부차관'},
#  {'id': '임인택', 'occupation': '보건복지부노인정책관'},
#  {'id': '이기일', 'occupation': '보건복지부보육정책관'},
#  {'id': '변성미', 'occupation': '보건복지부보육사업기획과'},
#  {'id': '조남권', 'occupation': '보건복지부연금정책국장'},
#  {'id': '김기선', 'occupation': '위원'},
#  {'id': '김기남', 'occupation': '보건복지부국민연금재정과장'},
#  {'id': '이준균', 'occupation': '보건복지부정책기획관'},
#  {'id': '김재원', 'occupation': '위원'},
#  {'id': '양승조', 'occupation': '위원'},
#  {'id': '김미희', 'occupation': '위원'},
#  {'id': '인재근', 'occupation': '위원'},
#  {'id': '정재인', 'occupation': '전문위원'},
#  {'id': '최영현', 'occupation': '보건복지부기획조정실장'},
#  {'id': '권기창', 'occupation': '보건복지부국제협력관'}]
# ' 제329회국회(정기회) 국방위원회회의록(예산결산심사소위원회) 제1호'
# '20141107'
# [{'id': '김성찬', 'occupation': '소위원장'},
#  {'id': '박창명', 'occupation': '병무청장'},
#  {'id': '권기원', 'occupation': '전문위원'},
#  {'id': '진성준', 'occupation': '위원'},
#  {'id': '한기호', 'occupation': '위원'},
#  {'id': '백군기', 'occupation': '위원'},
#  {'id': '장갑수', 'occupation': '병무청기획조정관'},
#  {'id': '조규동', 'occupation': '병무청사회교육복무과장'},
#  {'id': '송영근', 'occupation': '위원'},
#  {'id': '성석호', 'occupation': '수석전문위원'},
#  {'id': '주호영', 'occupation': '위원'},
#  {'id': '김영재', 'occupation': '병무청정보기획과장'},
#  {'id': '최철준', 'occupation': '병무청감사담당관'},
#  {'id': '안규백', 'occupation': '위원'},
#  {'id': '정복양', 'occupation': '병무청병역조사과장'},
#  {'id': '백운집', 'occupation': '병무청징병검사과장'},
#  {'id': '이성수', 'occupation': '병무청병역자원국장'},
#  {'id': '김태화', 'occupation': '병무청입영동원국장'},
#  {'id': '김노운', 'occupation': '병무청사회복무국장'}]
# ' 제329회국회(정기회) 법제사법위원회회의록(법안심사제1소위원회) 제1호'
# '20141106'
# [{'id': '홍일표', 'occupation': '소위원장'},
#  {'id': '전해철', 'occupation': '위원'},
#  {'id': '임중호', 'occupation': '수석전문위원'},
#  {'id': '김현웅', 'occupation': '법무부차관'},
#  {'id': '이한성', 'occupation': '위원'},
#  {'id': '강형주', 'occupation': '법원행정처차장'},
#  {'id': '김도읍', 'occupation': '위원'},
#  {'id': '김진태', 'occupation': '위원'},
#  {'id': '서영교', 'occupation': '위원'},
#  {'id': '임내현', 'occupation': '위원'},
#  {'id': '서기호', 'occupation': '위원'},
#  {'id': '강남일', 'occupation': '전문위원'},
#  {'id': '이성규', 'occupation': '법무부국제형사과장'},
#  {'id': '김주현', 'occupation': '법무부검찰국장겸감찰관직무대리'},
#  {'id': '노철래', 'occupation': '의원'}]
# ' 제329회국회(정기회) 기획재정위원회회의록(예산결산기금심사소위원회) 제3호'
# '20141111'
# [{'id': '박명재', 'occupation': '소위원장'},
#  {'id': '류환민', 'occupation': '수석전문위원'},
#  {'id': '박범계', 'occupation': '위원'},
#  {'id': '김령', 'occupation': '한국투자공사경영관리본부장'},
#  {'id': '심재철', 'occupation': '위원'},
#  {'id': '박광온', 'occupation': '위원'},
#  {'id': '주형환', 'occupation': '기획재정부제1차관'},
#  {'id': '이명수', 'occupation': '법무부복지과'},
#  {'id': '박덕흠', 'occupation': '위원'},
#  {'id': '이원식', 'occupation': '기획재정부국고국장'},
#  {'id': '오제세', 'occupation': '위원'},
#  {'id': '윤석호', 'occupation': '기획재정부국유재산조정과장'},
#  {'id': '김승기', 'occupation': '전문위원'},
#  {'id': '김철주', 'occupation': '기획재정부기획조정실장'},
#  {'id': '천홍욱', 'occupation': '관세청차장'},
#  {'id': '이태원', 'occupation': '조달청차장'},
#  {'id': '정규남', 'occupation': '통계청차장'},
#  {'id': '김봉래', 'occupation': '국세청차장'},
#  {'id': '서대원', 'occupation': '국세청기획조정관'},
#  {'id': '이돈현', 'occupation': '관세청기획조정관'},
#  {'id': '장경순', 'occupation': '조달청기획조정관'},
#  {'id': '허남덕', 'occupation': '통계청기획조정관'}]
# ' 제329회국회(정기회) 환경노동위원회회의록(법안심사소위원회) 제6호'
# '20141208'
# [{'id': '김양건', 'occupation': '전문위원'},
#  {'id': '고영선', 'occupation': '고용노동부차관'},
#  {'id': '최봉홍', 'occupation': '위원'},
#  {'id': '우원식', 'occupation': '위원'},
#  {'id': '안경덕', 'occupation': '고용노동부산재예방보상정책국장'},
#  {'id': '김용남', 'occupation': '위원'},
#  {'id': '은수미', 'occupation': '위원'},
#  {'id': '장하나', 'occupation': '위원'},
#  {'id': '이인영', 'occupation': '소위원장'},
#  {'id': '고동우', 'occupation': '고용노동부산업보건과장'},
#  {'id': '권성동', 'occupation': '소위원장'},
#  {'id': '이인영', 'occupation': '위원'},
#  {'id': '민현주', 'occupation': '위원'},
#  {'id': '한공식', 'occupation': '수석전문위원'},
#  {'id': '심경우', 'occupation': '고용노동부기획조정실장'},
#  {'id': '이재흥', 'occupation': '고용노동부고용정책실장'},
#  {'id': '권영순', 'occupation': '고용노동부노동정책실장'},
#  {'id': '김종열', 'occupation': '고용노동부정책기획관'},
#  {'id': '정형우', 'occupation': '고용노동부노동시장정책관'},
#  {'id': '나영돈', 'occupation': '고용노동부직업능력정책관'},
#  {'id': '문기섭', 'occupation': '고용노동부고용서비스정책관'},
#  {'id': '박화진', 'occupation': '고용노동부인력수급정책국장'},
#  {'id': '이수영', 'occupation': '고용노동부고령사회인력심의관'},
#  {'id': '권혁태', 'occupation': '고용노동부근로개선정책관'},
#  {'id': '임무송', 'occupation': '고용노동부노사협력정책관'},
#  {'id': '송문현', 'occupation': '고용노동부공공노사정책관'}]
# ' 제330회국회(임시회) 국토교통위원회회의록(국토법안심사소위원회) 제1호'
# '20141223'
# [{'id': '김성태', 'occupation': '소위원장'},
#  {'id': '정성호', 'occupation': '위원'},
#  {'id': '허태수', 'occupation': '수석전문위원'},
#  {'id': '김경식', 'occupation': '국토교통부제1차관'},
#  {'id': '이노근', 'occupation': '위원'},
#  {'id': '변재일', 'occupation': '위원'},
#  {'id': '이미경', 'occupation': '위원'},
#  {'id': '金熙國', 'occupation': '위원'},
#  {'id': '이언주', 'occupation': '위원'},
#  {'id': '정영진', 'occupation': '입법조사관'},
#  {'id': '정병윤', 'occupation': '국토교통부국토도시실장'},
#  {'id': '윤성원', 'occupation': '국토교통부도시정책관'},
#  {'id': '이장우', 'occupation': '위원'},
#  {'id': '박성호', 'occupation': '위원'},
#  {'id': '손태락', 'occupation': '국토교통부주택토지실장'}]
# ' 제330회국회(임시회) 법제사법위원회회의록(법안심사제1소위원회) 제2호'
# '20150108'
# [{'id': '홍일표', 'occupation': '소위원장'},
#  {'id': '남궁석', 'occupation': '수석전문위원'},
#  {'id': '강남일', 'occupation': '전문위원'},
#  {'id': '김현웅', 'occupation': '법무부차관'},
#  {'id': '강형주', 'occupation': '법원행정처차장'},
#  {'id': '전해철', 'occupation': '위원'},
#  {'id': '이한성', 'occupation': '위원'},
#  {'id': '임내현', 'occupation': '위원'},
#  {'id': '전지원', 'occupation': '법원행정처사법지원총괄심의관'},
#  {'id': '김진태', 'occupation': '위원'},
#  {'id': '정승면', 'occupation': '법무부법무심의관'},
#  {'id': '김도읍', 'occupation': '위원'},
#  {'id': '정인창', 'occupation': '법무부법무실장'},
#  {'id': '서기호', 'occupation': '위원'},
#  {'id': '임종헌', 'occupation': '법원행정처기획조정실장'},
#  {'id': '서영교', 'occupation': '위원'},
#  {'id': '김병천', 'occupation': '입법조사관'},
#  {'id': '백승주', 'occupation': '국방부차관'},
#  {'id': '심태규', 'occupation': '전문위원'}]
# ' 제330회국회(임시회) 외교통일위원회회의록(법안심사소위원회) 제1호'
# '20150106'
# [{'id': '심윤조', 'occupation': '소위원장'},
#  {'id': '배용근', 'occupation': '전문위원'},
#  {'id': '황부기', 'occupation': '통일부차관'},
#  {'id': '김성곤', 'occupation': '위원'},
#  {'id': '나경원', 'occupation': '위원'},
#  {'id': '심재권', 'occupation': '위원'},
#  {'id': '정순임', 'occupation': '입법조사관'},
#  {'id': '이종후', 'occupation': '수석전문위원'},
#  {'id': '배용준', 'occupation': '전문위원'},
#  {'id': '천해성', 'occupation': '통일부통일정책실장'},
#  {'id': '백태현', 'occupation': '통일부교류협력국장'}]
# ' 제331회국회(임시회) 법제사법위원회회의록(법안심사제2소위원회) 제1호'
# '20150224'
# [{'id': '전해철', 'occupation': '소위원장'},
#  {'id': '남궁석', 'occupation': '수석전문위원'},
#  {'id': '김용진', 'occupation': '기획재정부사회예산심의관'},
#  {'id': '최완근', 'occupation': '국가보훈처차장'},
#  {'id': '홍일표', 'occupation': '위원'},
#  {'id': '노철래', 'occupation': '위원'},
#  {'id': '이춘석', 'occupation': '위원'},
#  {'id': '고승범', 'occupation': '금융위원회사무처장'},
#  {'id': '심태규', 'occupation': '전문위원'},
#  {'id': '허원제', 'occupation': '방송통신위원회부위원장'},
#  {'id': '배진철', 'occupation': '공정거래위원회기업거래정책국장'},
#  {'id': '이한성', 'occupation': '위원'},
#  {'id': '권용현', 'occupation': '여성가족부차관'},
#  {'id': '임내현', 'occupation': '위원'},
#  {'id': '김진태', 'occupation': '위원'},
#  {'id': '임재주', 'occupation': '전문위원'},
#  {'id': '이상원', 'occupation': '경찰청차장'},
#  {'id': '문재도', 'occupation': '산업통상자원부제2차관'},
#  {'id': '구슬이', 'occupation': '입법조사관'},
#  {'id': '서영교', 'occupation': '위원'},
#  {'id': '강남일', 'occupation': '전문위원'}]
# ' 제332회국회(임시회) 교육문화체육관광위원회회의록(법안심사소위원회) 제2호'
# '20150430'
# [{'id': '신성범', 'occupation': '소위원장'},
#  {'id': '정재룡', 'occupation': '수석전문위원'},
#  {'id': '김관복', 'occupation': '교육부기획조정실장'},
#  {'id': '박홍근', 'occupation': '위원'},
#  {'id': '윤관석', 'occupation': '위원'},
#  {'id': '전완희', 'occupation': '입법조사관'},
#  {'id': '김태년', 'occupation': '위원'},
#  {'id': '이종훈', 'occupation': '위원'},
#  {'id': '박혜자', 'occupation': '위원'},
#  {'id': '배재정', 'occupation': '위원'},
#  {'id': '이에리사', 'occupation': '위원'},
#  {'id': '이정화', 'occupation': '전문위원'},
#  {'id': '김회선', 'occupation': '위원'},
#  {'id': '이상일', 'occupation': '위원'},
#  {'id': '김종', 'occupation': '문화체육관광부제2차관'},
#  {'id': '김철민', 'occupation': '문화체육관광부관광정책관'},
#  {'id': '김재원', 'occupation': '문화체육관광부체육관광정책실장'}]
# ' 제332회국회(임시회) 법제사법위원회회의록(법안심사제1소위원회) 제2호'
# '20150501'
# [{'id': '홍일표', 'occupation': '소위원장'},
#  {'id': '심태규', 'occupation': '전문위원'},
#  {'id': '이한성', 'occupation': '위원'},
#  {'id': '전해철', 'occupation': '위원'},
#  {'id': '김주현', 'occupation': '법무부차관'},
#  {'id': '강형주', 'occupation': '법원행정처차장'},
#  {'id': '김진태', 'occupation': '위원'},
#  {'id': '서기호', 'occupation': '위원'},
#  {'id': '김도읍', 'occupation': '위원'},
#  {'id': '박종원', 'occupation': '국토교통부부동산평가과장'},
#  {'id': '서영교', 'occupation': '위원'},
#  {'id': '임내현', 'occupation': '위원'},
#  {'id': '남궁석', 'occupation': '수석전문위원'},
#  {'id': '임재주', 'occupation': '전문위원'},
#  {'id': '강남일', 'occupation': '전문위원'}]
# ' 제332회국회(임시회) 법제사법위원회회의록(법안심사제1소위원회) 제3호'
# '20150504'
# [{'id': '홍일표', 'occupation': '소위원장'},
#  {'id': '심태규', 'occupation': '전문위원'},
#  {'id': '강형주', 'occupation': '법원행정처차장'},
#  {'id': '서기호', 'occupation': '위원'},
#  {'id': '김진태', 'occupation': '위원'},
#  {'id': '김주현', 'occupation': '법무부차관'},
# ...
#  {'id': '강창일', 'occupation': '위원'},
#  {'id': '이재정', 'occupation': '위원'},
#  {'id': '정성희', 'occupation': '전문위원'},
#  {'id': '서승우', 'occupation': '행정안전부자치분권정책관'},
#  {'id': '신열우', 'occupation': '소방청차장'},
#  {'id': '이채익', 'occupation': '의원'},
#  {'id': '이창림', 'occupation': '수석전문위원'},
#  {'id': '김한정', 'occupation': '위원'},
#  {'id': '김영호', 'occupation': '위원'},
#  {'id': '강성조', 'occupation': '행정안전부지방재정정책관'},
#  {'id': '윤종인', 'occupation': '행정안전부차관'},
#  {'id': '윤재옥', 'occupation': '위원'},
#  {'id': '정양석', 'occupation': '의원'},
#  {'id': '박완수', 'occupation': '위원'},
#  {'id': '김영우', 'occupation': '의원'},
#  {'id': '홍문표', 'occupation': '위원'},
#  {'id': '류임철', 'occupation': '행정안전부정책기획관'}]
# ' 제368회국회(임시회·폐회중) 행정안전위원회회의록(제천화재관련평가소위원회) 제1호'
# '20190509'
# [{'id': '권은희', 'occupation': '소위원장'},
#  {'id': '변수남', 'occupation': '전라남도소방본부장'},
#  {'id': '홍영근', 'occupation': '소방청화재대응조사과장'},
#  {'id': '소병훈', 'occupation': '위원'},
#  {'id': '김영호', 'occupation': '위원'},
#  {'id': '유민봉', 'occupation': '위원'},
#  {'id': '鄭仁和', 'occupation': '위원'},
#  {'id': '이창림', 'occupation': '수석전문위원'}]
# ' 제369회국회(임시회) 교육위원회회의록(법안심사소위원회) 제1호'
# '20190626'
# [{'id': '조승래', 'occupation': '소위원장'},
#  {'id': '정홍진', 'occupation': '입법조사관'},
#  {'id': '서영교', 'occupation': '위원'},
#  {'id': '곽상도', 'occupation': '위원'},
#  {'id': '전희경', 'occupation': '위원'},
#  {'id': '조기열', 'occupation': '전문위원'},
#  {'id': '박백범', 'occupation': '교육부차관'},
#  {'id': '정재룡', 'occupation': '수석전문위원'},
#  {'id': '박찬대', 'occupation': '위원'},
#  {'id': '임재훈', 'occupation': '위원'},
#  {'id': '최상대', 'occupation': '기획재정부사회예산심의관'},
#  {'id': '박경미', 'occupation': '위원'},
#  {'id': '주명현', 'occupation': '교육부기획조정실장'}]
# ' 제369회국회(임시회) 교육위원회회의록(법안심사소위원회) 제3호'
# '20190711'
# [{'id': '조승래', 'occupation': '소위원장'},
#  {'id': '이승재', 'occupation': '수석전문위원'},
#  {'id': '박백범', 'occupation': '교육부차관'},
#  {'id': '곽상도', 'occupation': '위원'},
#  {'id': '서영교', 'occupation': '위원'},
#  {'id': '전희경', 'occupation': '위원'},
#  {'id': '정영린', 'occupation': '교육부교육시설과장'},
#  {'id': '신종숙', 'occupation': '전문위원'},
#  {'id': '김현아', 'occupation': '위원'},
#  {'id': '박경미', 'occupation': '위원'},
#  {'id': '강정자', 'occupation': '교육부교원정책과장'},
#  {'id': '박찬대', 'occupation': '위원'},
#  {'id': '임재훈', 'occupation': '위원'},
#  {'id': '주명현', 'occupation': '교육부기획조정실장'}]
# ' 제369회국회(임시회) 교육위원회회의록(안건조정위원회) 제1호'
# '20190708'
# [{'id': '서영교', 'occupation': '조정위원장직무대행'},
#  {'id': '곽상도', 'occupation': '위원'},
#  {'id': '박경미', 'occupation': '위원'},
#  {'id': '조승래', 'occupation': '조정위원장'},
#  {'id': '임재훈', 'occupation': '위원'},
#  {'id': '서영교', 'occupation': '위원'},
#  {'id': '정홍진', 'occupation': '입법조사관'},
#  {'id': '이승재', 'occupation': '수석전문위원'},
#  {'id': '박백범', 'occupation': '교육부차관'}]
# ' 제369회국회(임시회) 국토교통위원회회의록(교통법안심사소위원회) 제2호'
# '20190716'
# [{'id': '윤관석', 'occupation': '소위원장'},
#  {'id': '박희석', 'occupation': '전문위원'},
#  {'id': '이현재', 'occupation': '위원'},
#  {'id': '김경욱', 'occupation': '국토교통부제2차관'},
#  {'id': '김상훈', 'occupation': '위원'},
#  {'id': '박홍근', 'occupation': '위원'},
#  {'id': '민경욱', 'occupation': '위원'},
#  {'id': '박재호', 'occupation': '위원'},
#  {'id': '송석준', 'occupation': '위원'},
#  {'id': '안호영', 'occupation': '위원'},
#  {'id': '정경훈', 'occupation': '국토교통부교통물류실장'},
#  {'id': '조응천', 'occupation': '위원'},
#  {'id': '이용호', 'occupation': '위원'}]
# ' 제369회국회(임시회) 기획재정위원회회의록(예산결산기금심사소위원회) 제1호'
# '20190715'
# [{'id': '김성식', 'occupation': '소위원장'},
#  {'id': '엄용수', 'occupation': '위원'},
#  {'id': '석영환', 'occupation': '수석전문위원'},
#  {'id': '구윤철', 'occupation': '기획재정부제2차관'},
#  {'id': '심재철', 'occupation': '위원'},
#  {'id': '박충근', 'occupation': '기획재정부대외경제국장'},
#  {'id': '이형렬', 'occupation': '기획재정부대외경제총괄과장'},
#  {'id': '강병원', 'occupation': '위원'},
#  {'id': '백명기', 'occupation': '조달청차장'},
#  {'id': '강경훈', 'occupation': '조달청구매사업국장'},
#  {'id': '김정우', 'occupation': '위원'},
#  {'id': '박태형', 'occupation': '전문위원'},
#  {'id': '문성유', 'occupation': '기획재정부기획조정실장'},
#  {'id': '박성동', 'occupation': '기획재정부국고국장'},
#  {'id': '안도걸', 'occupation': '기획재정부예산총괄심의관'}]
# ' 제369회국회(임시회) 여성가족위원회회의록(법안심사소위원회) 제2호'
# '20190627'
# [{'id': '김수민', 'occupation': '소위원장'},
#  {'id': '송희경', 'occupation': '위원'},
#  {'id': '정춘숙', 'occupation': '위원'},
#  {'id': '신경민', 'occupation': '위원'},
#  {'id': '배용근', 'occupation': '수석전문위원'},
#  {'id': '김희경', 'occupation': '여성가족부차관'},
#  {'id': '표창원', 'occupation': '위원'},
#  {'id': '송옥주', 'occupation': '위원'},
#  {'id': '전태석', 'occupation': '법무부법무심의관'},
#  {'id': '최종혁', 'occupation': '경찰청규제개혁법무담당관'},
#  {'id': '노지선', 'occupation': '양육비이행관리원가족상담본부장'},
#  {'id': '이정심', 'occupation': '여성가족부가족정책관'},
#  {'id': '차인순', 'occupation': '입법심의관'},
#  {'id': '김중열', 'occupation': '여성가족부기획조정실장'},
#  {'id': '윤효식', 'occupation': '여성가족부청소년가족정책실장'},
#  {'id': '황윤정', 'occupation': '여성가족부권익증진국장'},
#  {'id': '최창행', 'occupation': '여성가족부정책기획관'},
#  {'id': '박난숙', 'occupation': '여성가족부청소년정책관'},
#  {'id': '황창선', 'occupation': '경찰청교통기획과장'},
#  {'id': '전요섭', 'occupation': '경찰청금융위원회은행과장'}]
# ' 제369회국회(임시회) 행정안전위원회회의록(제천화재관련평가소위원회) 제2호'
# '20190711'
# [{'id': '권은희', 'occupation': '소위원장'},
#  {'id': '김성태', 'occupation': '위원'},
#  {'id': '鄭仁和', 'occupation': '위원'},
#  {'id': '소병훈', 'occupation': '위원'},
#  {'id': '김영호', 'occupation': '위원'},
#  {'id': '민동일', 'occupation': '제천화재유가족대표'},
#  {'id': '김영조', 'occupation': '제천화재유가족대표'},
#  {'id': '한창섭', 'occupation': '충청북도행정부지사'},
#  {'id': '이경태', 'occupation': '제천시부시장'},
#  {'id': '이진복', 'occupation': '위원'},
#  {'id': '권대윤', 'occupation': '충청북도소방본부장'},
#  {'id': '조의섭', 'occupation': '수석전문위원'}]
# ' 제370회국회(임시회) 국토교통위원회회의록(교통법안심사소위원회) 제1호'
# '20190822'
# [{'id': '윤관석', 'occupation': '소위원장'},
#  {'id': '이현재', 'occupation': '위원'},
#  {'id': '박홍근', 'occupation': '위원'},
#  {'id': '유상조', 'occupation': '전문위원'},
#  {'id': '박선호', 'occupation': '국토교통부제1차관'},
#  {'id': '김용석', 'occupation': '국토교통부도로국장'},
#  {'id': '박병석', 'occupation': '국토교통부도로투자지원과장'},
#  {'id': '손명수', 'occupation': '국토교통부기획조정실장'},
#  {'id': '박재호', 'occupation': '위원'},
#  {'id': '이용호', 'occupation': '위원'},
#  {'id': '김상훈', 'occupation': '위원'},
#  {'id': '황성규', 'occupation': '국토교통부철도국장'},
#  {'id': '권용복', 'occupation': '국토교통부항공정책실장'},
#  {'id': '송석준', 'occupation': '위원'},
#  {'id': '조응천', 'occupation': '위원'}]
# ' 제370회국회(임시회) 환경노동위원회회의록(환경소위원회) 제1호'
# '20190821'
# [{'id': '한정애', 'occupation': '소위원장'},
#  {'id': '임이자', 'occupation': '위원'},
#  {'id': '신보라', 'occupation': '위원'},
#  {'id': '신창현', 'occupation': '위원'},
#  {'id': '윤광식', 'occupation': '전문위원'},
#  {'id': '박천규', 'occupation': '환경부차관'},
#  {'id': '송옥주', 'occupation': '위원'},
#  {'id': '강효상', 'occupation': '위원'},
#  {'id': '금한승', 'occupation': '환경부대기환경정책관'},
#  {'id': '김동철', 'occupation': '위원'},
#  {'id': '주대영', 'occupation': '환경부정책기획관'},
#  {'id': '이호중', 'occupation': '환경부자연보전정책관'},
#  {'id': '이영기', 'occupation': '환경부자원순환정책관'},
#  {'id': '김동구', 'occupation': '환경부환경경제정책관'},
#  {'id': '하미나', 'occupation': '환경부환경보건정책관'}]
# ' 제371회국회(정기회) 국방위원회회의록(법률안심사소위원회) 제2호'
# '20190920'
# [{'id': '백승주', 'occupation': '소위원장'},
#  {'id': '박재민', 'occupation': '국방부차관'},
#  {'id': '김부년', 'occupation': '수석전문위원'},
#  {'id': '안도걸', 'occupation': '기획재정부예산총괄심의관'},
#  {'id': '김진표', 'occupation': '위원'},
#  {'id': '민홍철', 'occupation': '위원'},
#  {'id': '서청원', 'occupation': '위원'},
#  {'id': '김중로', 'occupation': '위원'},
#  {'id': '김병기', 'occupation': '위원'},
#  {'id': '황영철', 'occupation': '위원'},
#  {'id': '오명호', 'occupation': '전문위원'},
#  {'id': '박경수', 'occupation': '국방부법무관리관'},
#  {'id': '윤문학', 'occupation': '국방부인사기획관'},
#  {'id': '조경자', 'occupation': '국방부보건복지관'},
#  {'id': '김일동', 'occupation': '국방부전력정책관'},
#  {'id': '정재준', 'occupation': '방위사업청방위사업정책국장'},
#  {'id': '박승홍', 'occupation': '방위사업청방위산업진흥국장'},
#  {'id': '서형진', 'occupation': '방위사업청기반전력사업지원부장'}]
# ' 제371회국회(정기회) 국방위원회회의록(법률안심사소위원회) 제5호'
# '20191118'
# [{'id': '백승주', 'occupation': '소위원장'},
#  {'id': '박재민', 'occupation': '국방부차관'},
#  {'id': '김부년', 'occupation': '수석전문위원'},
#  {'id': '민홍철', 'occupation': '위원'},
#  {'id': '김진표', 'occupation': '위원'},
#  {'id': '서청원', 'occupation': '위원'},
#  {'id': '김일동', 'occupation': '국방부전력정책관'},
#  {'id': '김중로', 'occupation': '위원'},
#  {'id': '오명호', 'occupation': '전문위원'},
#  {'id': '조중현', 'occupation': '대한공중보건의사협의회장'},
#  {'id': '김태화', 'occupation': '병무청차장'},
#  {'id': '김병기', 'occupation': '위원'},
#  {'id': '박경수', 'occupation': '국방부법무관리관'},
#  {'id': '윤문학', 'occupation': '국방부인사기획관'},
#  {'id': '김도균', 'occupation': '국방부대북정책관'},
#  {'id': '박길성', 'occupation': '국방부군사시설기획관'},
#  {'id': '조경자', 'occupation': '국방부보건복지관'},
#  {'id': '임재하', 'occupation': '병무청기획조정관'},
#  {'id': '조복연', 'occupation': '병무청입영동원국장'},
#  {'id': '홍승미', 'occupation': '병무청사회복무국장'},
#  {'id': '한명진', 'occupation': '방위사업청차장'},
#  {'id': '이상훈', 'occupation': '방위사업청감사관'},
#  {'id': '정재준', 'occupation': '방위사업청방위사업정책국장'},
#  {'id': '박승흥', 'occupation': '방위사업청방위산업진흥국장'},
#  {'id': '김상모', 'occupation': '방위사업청국방기술보호국장'}]
# ' 제371회국회(정기회) 외교통일위원회회의록(미주소위원회) 제1호'
# '20191112'
# [{'id': '추미애', 'occupation': '소위원장'},
#  {'id': '심재권', 'occupation': '위원'},
#  {'id': '정진석', 'occupation': '위원'},
#  {'id': '이인영', 'occupation': '위원'},
#  {'id': '정병국', 'occupation': '위원'},
#  {'id': '조세영', 'occupation': '외교부제1차관'},
#  {'id': '고윤주', 'occupation': '외교부북미국장'},
#  {'id': '이성호', 'occupation': '외교부한미방위비분담협상TF정부부대표'},
#  {'id': '권기원', 'occupation': '수석전문위원'},
#  {'id': '최선영', 'occupation': '전문위원'},
#  {'id': '강형식', 'occupation': '외교부해외안전관리기획관'},
#  {'id': '황경태', 'occupation': '외교부중남미국심의관'},
#  {'id': '박장호', 'occupation': '외교부북핵외교기획단부단장'}]
# ' 제371회국회(정기회) 외교통일위원회회의록(법안심사소위원회) 제2호'
# '20191121'
# [{'id': '김재경', 'occupation': '소위원장'},
#  {'id': '이태호', 'occupation': '외교부제2차관'},
#  {'id': '권기원', 'occupation': '수석전문위원'},
#  {'id': '추미애', 'occupation': '위원'},
#  {'id': '김부겸', 'occupation': '위원'},
#  {'id': '장영현', 'occupation': '국무조정실개발협력정책관'},
#  {'id': '유기준', 'occupation': '위원'},
#  {'id': '박정', 'occupation': '위원'},
#  {'id': '유민봉', 'occupation': '위원'},
#  {'id': '오현주', 'occupation': '외교부개발협력국장'},
#  {'id': '우광진', 'occupation': '행정안전부사회통합지원과장'},
#  {'id': '송영길', 'occupation': '위원'},
#  {'id': '박주선', 'occupation': '위원'},
#  {'id': '최선영', 'occupation': '전문위원'},
#  {'id': '허장', 'occupation': '기획재정부개발금융국장'}]
# ' 제371회국회(정기회) 외교통일위원회회의록(신남방소위원회) 제1호'
# '20191113'
# [{'id': '박주선', 'occupation': '소위원장'},
#  {'id': '원혜영', 'occupation': '위원'},
#  {'id': '유기준', 'occupation': '위원'},
#  {'id': '조세영', 'occupation': '외교부제1차관'},
#  {'id': '이석현', 'occupation': '위원'},
#  {'id': '권기원', 'occupation': '수석전문위원'},
#  {'id': '최선영', 'occupation': '전문위원'},
#  {'id': '김영완', 'occupation': '외교부조정기획관'},
#  {'id': '박재경', 'occupation': '외교부아세안국심의관'}]
# ' 제371회국회(정기회) 외교통일위원회회의록(예산·결산·기금심사소위원회) 제1호'
# '20190917'
# [{'id': '이수혁', 'occupation': '소위원장'},
#  {'id': '조세영', 'occupation': '외교부제1차관'},
#  {'id': '권기원', 'occupation': '수석전문위원'},
#  {'id': '천정배', 'occupation': '위원'},
#  {'id': '박병석', 'occupation': '위원'},
#  {'id': '정진석', 'occupation': '위원'},
#  {'id': '원유철', 'occupation': '위원'},
#  {'id': '이석현', 'occupation': '위원'},
#  {'id': '강영필', 'occupation': '한국국제교류재단기획협력이사'},
#  {'id': '기춘', 'occupation': '재외동포재단사업이사'},
#  {'id': '서호', 'occupation': '통일부차관'},
#  {'id': '최선영', 'occupation': '전문위원'},
#  {'id': '정양석', 'occupation': '위원'},
#  {'id': '이승환', 'occupation': '민주평화통일자문회의사무처장'},
#  {'id': '원혜영', 'occupation': '위원'}]
# ' 제371회국회(정기회) 외교통일위원회회의록(유럽·아프리카소위원회) 제1호'
# '20191118'
# [{'id': '유민봉', 'occupation': '소위원장'},
#  {'id': '정병국', 'occupation': '위원'},
#  {'id': '천정배', 'occupation': '위원'},
#  {'id': '조세영', 'occupation': '외교부제1차관'},
#  {'id': '양동한', 'occupation': '외교부양자경제외교국장'},
#  {'id': '김필우', 'occupation': '외교부유럽국장'},
#  {'id': '최연호', 'occupation': '한·아프리카재단이사장'},
#  {'id': '박정', 'occupation': '위원'},
#  {'id': '고경석', 'occupation': '외교부아프리카중동국심의관'},
#  {'id': '김부겸', 'occupation': '위원'},
#  {'id': '권기원', 'occupation': '수석전문위원'},
#  {'id': '최선영', 'occupation': '전문위원'}]
# ' 제371회국회(정기회) 행정안전위원회회의록(안건조정위원회) 제2호'
# '20190923'
# [{'id': '홍익표', 'occupation': '조정위원장'},
#  {'id': '윤재옥', 'occupation': '위원'},
#  {'id': '정연수', 'occupation': '입법조사관'},
#  {'id': '권은희', 'occupation': '위원'},
#  {'id': '이채익', 'occupation': '위원'},
#  {'id': '조의섭', 'occupation': '수석전문위원'},
#  {'id': '김민기', 'occupation': '위원'},
#  {'id': '이재정', 'occupation': '위원'},
#  {'id': '이흥교', 'occupation': '소방청기획조정관'},
#  {'id': '이인재', 'occupation': '행정안전부기획조정실장'},
#  {'id': '정성희', 'occupation': '전문위원'},
#  {'id': '오병권', 'occupation': '행정안전부정책기획관'},
#  {'id': '서승우', 'occupation': '행정안전부지방행정정책관'}]
# ' 제371회국회(정기회) 환경노동위원회회의록(예산결산기금심사소위원회) 제5호'
# '20191107'
# [{'id': '김동철', 'occupation': '소위원장'},
#  {'id': '이장우', 'occupation': '위원'},
#  {'id': '윤광식', 'occupation': '전문위원'},
#  {'id': '설훈', 'occupation': '위원'},
#  {'id': '박천규', 'occupation': '환경부차관'},
#  {'id': '임이자', 'occupation': '위원'},
#  {'id': '한정애', 'occupation': '위원'},
#  {'id': '김종석', 'occupation': '기상청장'},
#  {'id': '송옥주', 'occupation': '위원'},
#  {'id': '김양건', 'occupation': '수석전문위원'},
#  {'id': '강효상', 'occupation': '위원'},
#  {'id': '임서정', 'occupation': '고용노동부차관'},
#  {'id': '전현희', 'occupation': '위원'},
#  {'id': '박종필', 'occupation': '고용노동부청년고용정책관'},
#  {'id': '정형우', 'occupation': '일자리위원회일자리기획단부단장'},
#  {'id': '김영훈', 'occupation': '환경부물통합정책국장'},
#  {'id': '박미자', 'occupation': '환경부물환경정책국장'},
#  {'id': '주대영', 'occupation': '환경부정책기획관'},
#  {'id': '이호중', 'occupation': '환경부자연보전정책관'},
#  {'id': '신도식', 'occupation': '기상청기획조정관'},
#  {'id': '송홍석', 'occupation': '고용노동부통합고용정책국장'},
#  {'id': '선우정택', 'occupation': '고용노동부정책기획관'},
#  {'id': '김영중', 'occupation': '고용노동부노동시장정책관'},
#  {'id': '이정한', 'occupation': '고용노동부고용서비스정책관'},
#  {'id': '이헌수', 'occupation': '고용노동부공공노사정책관'}]
# ' 제372회국회(임시회) 환경노동위원회회의록(환경소위원회) 제2호'
# '20191212'
# [{'id': '한정애', 'occupation': '소위원장'},
#  {'id': '윤광식', 'occupation': '전문위원'},
#  {'id': '박천규', 'occupation': '환경부차관'},
#  {'id': '신창현', 'occupation': '위원'},
#  {'id': '하미나', 'occupation': '환경부환경보건정책관'},
#  {'id': '전현희', 'occupation': '위원'},
#  {'id': '임이자', 'occupation': '위원'},
#  {'id': '강효상', 'occupation': '위원'},
#  {'id': '송옥주', 'occupation': '위원'},
#  {'id': '신보라', 'occupation': '위원'},
#  {'id': '주대영', 'occupation': '환경부정책기획관'}]
# ' 제376회국회(임시회) 기획재정위원회회의록(예산결산기금심사소위원회) 제1호'
# '20200311'
# [{'id': '김성식', 'occupation': '소위원장'},
#  {'id': '석영환', 'occupation': '수석전문위원'},
#  {'id': '송병철', 'occupation': '전문위원'},
#  {'id': '김용범', 'occupation': '기획재정부제1차관'},
#  {'id': '추경호', 'occupation': '위원'},
#  {'id': '김정우', 'occupation': '위원'},
#  {'id': '강병원', 'occupation': '위원'},
#  {'id': '윤후덕', 'occupation': '위원'},
#  {'id': '안도걸', 'occupation': '기획재정부예산총괄심의관'},
#  {'id': '백남수', 'occupation': '한국수출입은행경영기획본부장'},
#  {'id': '백승주', 'occupation': '기획재정부기획조정실장'},
#  {'id': '이종욱', 'occupation': '기획재정부국고국장'},
#  {'id': '류상민', 'occupation': '기획재정부대외경제국장'},
#  {'id': '김태주', 'occupation': '기획재정부조세총괄정책관'}]
# ' 제376회국회(임시회) 행정안전위원회회의록(법안심사소위원회) 제1호'
# '20200304'
# [{'id': '이채익', 'occupation': '소위원장'},
#  {'id': '표창원', 'occupation': '위원'},
#  {'id': '장정숙', 'occupation': '위원'},
#  {'id': '정성희', 'occupation': '전문위원'},
#  {'id': '장하연', 'occupation': '경찰청차장'},
#  {'id': '김병관', 'occupation': '위원'},
#  {'id': '이영상', 'occupation': '경찰청교통국장'},
#  {'id': '황창선', 'occupation': '경찰청교통기획과장'},
#  {'id': '윤재옥', 'occupation': '위원'},
#  {'id': '김한정', 'occupation': '위원'},
#  {'id': '김영호', 'occupation': '위원'},
#  {'id': '양석용', 'occupation': '법원행정처형사지원심의관'},
#  {'id': '진교훈', 'occupation': '경찰청정보국장'},
#  {'id': '김민기', 'occupation': '위원'}]
# ' 제376회국회(임시회) 환경노동위원회회의록(예산결산기금심사소위원회) 제1호'
# '20200310'
# [{'id': '송주아', 'occupation': '전문위원'},
#  {'id': '임서정', 'occupation': '고용노동부차관'},
#  {'id': '설훈', 'occupation': '위원'},
#  {'id': '임이자', 'occupation': '위원'},
#  {'id': '선우정택', 'occupation': '고용노동부정책기획관'},
#  {'id': '송옥주', 'occupation': '위원'},
#  {'id': '김영중', 'occupation': '고용노동부노동시장정책관'},
#  {'id': '전현희', 'occupation': '위원'},
#  {'id': '한정애', 'occupation': '위원'},
#  {'id': '이정미', 'occupation': '위원'},
#  {'id': '이정한', 'occupation': '고용노동부고용서비스정책관'},
#  {'id': '박종필', 'occupation': '고용노동부청년고용정책관'}]
# ' 제377회국회(임시회) 법제사법위원회회의록(법안심사제1소위원회) 제1호'
# '20200428'
# [{'id': '송기헌', 'occupation': '소위원장'},
#  {'id': '고기영', 'occupation': '법무부차관'},
#  {'id': '권태현', 'occupation': '전문위원'},
#  {'id': '김인겸', 'occupation': '법원행정처차장'},
#  {'id': '백혜련', 'occupation': '위원'},
#  {'id': '채이배', 'occupation': '위원'},
#  {'id': '정점식', 'occupation': '위원'},
#  {'id': '강호성', 'occupation': '법무부범죄예방정책국장'},
#  {'id': '유태석', 'occupation': '법무부형사법제과장'},
#  {'id': '김도읍', 'occupation': '위원'},
#  {'id': '전상수', 'occupation': '수석전문위원'},
#  {'id': '박장호', 'occupation': '전문위원'}]
# ' 제377회국회(임시회) 행정안전위원회회의록(예산·결산및기금심사소위원회) 제1호'
# '20200428'
# [{'id': '홍익표', 'occupation': '소위원장'},
#  {'id': '윤종인', 'occupation': '행정안전부차관'},
#  {'id': '김경희', 'occupation': '기획재정부행정국방예산심의관'},
#  {'id': '조의섭', 'occupation': '수석전문위원'},
#  {'id': '이진복', 'occupation': '위원'},
#  {'id': '김영우', 'occupation': '위원'},
#  {'id': '鄭仁和', 'occupation': '위원'},
#  {'id': '권미혁', 'occupation': '위원'},
#  {'id': '강창일', 'occupation': '위원'},
#  {'id': '박완수', 'occupation': '위원'},
#  {'id': '소병훈', 'occupation': '위원'}]
